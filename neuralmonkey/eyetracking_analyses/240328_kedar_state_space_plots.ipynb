# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Extracting a dataset preprocessed and ready for decoding (and other population analyses)

# %% [markdown]
# ### 1. Extract DFallpa using this helper function

# %%
from neuralmonkey.classes.population_mult import dfallpa_extraction_load_wrapper
animal = "Diego"
date = 230630
question = "PIG_BASE_trial" # holds variety of prepropoessing steps to clean data, specificalyl for PIG data.
list_time_windows = [(-0.6, 0.6)] # to slice data including just within this time window (realtive to events)
events_keep = ["00_fixon"]
combine_into_larger_areas = False
which_level = "saccade_fix_on"
SPIKES_VERSION = "tdt"
DFallpa = dfallpa_extraction_load_wrapper(animal, date, question, list_time_windows,
                                    which_level=which_level,
                                    events_keep = events_keep,
                                    combine_into_larger_areas=combine_into_larger_areas,
                                    HACK_RENAME_SHAPES=False,
                                          SPIKES_VERSION=SPIKES_VERSION)
# Out:
# Searching using this string:
# /home/kgg/mnt/Freiwald/ltian/recordings/*Diego*/*230630*/**
# Found this many paths:
# 1
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630/Diego-230630-124955
# session:  0
# Beh Sessions that exist on this date:  {230630: [(1, 'primsingridfixed6fDiego')]}
# ------------------------------
# Loading this neural session: 0
# Loading these beh expts: ['primsingridfixed6fDiego']
# Loading these beh sessions: [1]
# Using this beh_trial_map_list: [(1, 0)]
# Searching using this string:
# /home/kgg/mnt/Freiwald/ltian/recordings/*Diego*/*230630*/**
# Found this many paths:
# 1
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630/Diego-230630-124955
# {'filename_components_hyphened': ['Diego', '230630', '124955'], 'basedirs': ['/home/kgg/mnt/Freiwald/ltian/recordings/Diego', '/home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630'], 'basedirs_filenames': ['230630', 'Diego-230630-124955'], 'filename_final_ext': 'Diego-230630-124955', 'filename_final_noext': 'Diego-230630-124955'}
# FOund this path for spikes:  /home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630/Diego-230630-124955/spikes_tdt_quick-4
# == PATHS for this expt:
# raws  --  /home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630/Diego-230630-124955
# tank  --  /home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630/Diego-230630-124955/Diego-230630-124955
# spikes  --  /home/kgg/mnt/Freiwald/ltian/recordings/Diego/230630/Diego-230630-124955/spikes_tdt_quick-4
# final_dir_name  --  Diego-230630-124955
# time  --  124955
# pathbase_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955
# tank_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/data_tank.pkl
# spikes_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/data_spikes.pkl
# datall_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/data_datall.pkl
# events_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/events_photodiode.pkl
# mapper_st2dat_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/mapper_st2dat.pkl
# figs_local  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/figs
# metadata_units  --  /home/kgg/Desktop/neuralmonkey/neuralmonkey/metadat/units_Diego
# cached_dir  --  /data4/Kedar/neural_preprocess/recordings/Diego/230630/Diego-230630-124955/cached
# Sites metada path doesnt exist:  /home/kgg/Desktop/neuralmonkey/neuralmonkey/metadat/units/230630.yaml
# updating self.SitesDirty with:  ('sites_garbage', 'sites_error_spikes', 'sites_low_spk_magn')
# [_sitesdirty_update] skipping! since did not find:  sites_garbage
# [_sitesdirty_update] skipping! since did not find:  sites_error_spikes
# Printing whether spikes gotten (o) or not (-) because of spike peak to trough
# == Loading TDT tank
# ** Loading tank data from local (previusly cached)
# == Done
# ** MINIMAL_LOADING, therefore loading previuosly cached data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       8 which_level = "saccade_fix_on"
#       9 SPIKES_VERSION = "tdt"
# ---> 10 DFallpa = dfallpa_extraction_load_wrapper(animal, date, question, list_time_windows,
#      11                                     which_level=which_level,
#      12                                     events_keep = events_keep,
#      13                                     combine_into_larger_areas=combine_into_larger_areas,
#      14                                     HACK_RENAME_SHAPES=False,
#      15                                           SPIKES_VERSION=SPIKES_VERSION)
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/population_mult.py:674, in dfallpa_extraction_load_wrapper(animal, date, question, list_time_windows, which_level, events_keep, combine_into_larger_areas, exclude_bad_areas, bin_by_time_dur, bin_by_time_slide, slice_agg_slices, slice_agg_vars_to_split, slice_agg_concat_dim, LOAD_FROM_RSA_ANALY, rsa_ver_dist, rsa_subtr, rsa_agg, rsa_invar, SPIKES_VERSION, HACK_RENAME_SHAPES, substrokes_plot_preprocess, strokes_split_into_multiple_pa, fr_normalization_method, path_to_save_example_fr_normalization)
#     663     assert list_time_windows is not None
#     665     ############### PARAMS
#     666     # animal = "Diego"
#     667     # date = 230615
#    (...)
#     672
#     673     ## Load Snippets
# --> 674     MS = load_mult_session_helper(date, animal, spikes_version=SPIKES_VERSION)
#     675     DFallpa = dfallpa_extraction_load_wrapper_from_MS(MS, question, list_time_windows, which_level, events_keep,
#     676                                                       combine_into_larger_areas, exclude_bad_areas, bin_by_time_dur,
#     677                                                       bin_by_time_slide, slice_agg_slices, slice_agg_vars_to_split,
#    (...)
#     681                                                       fr_normalization_method=fr_normalization_method,
#     682                                                       path_to_save_example_fr_normalization=path_to_save_example_fr_normalization)
#     684 # cleanup
#     685 # for pa in DFallpa.
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:148, in load_mult_session_helper(DATE, animal, dataset_beh_expt, expt, MINIMAL_LOADING, units_metadat_fail_if_no_exist, spikes_version)
#     139 print("session: ", rec_session)
#     141 # ============= RUN
#     142 # beh_session = rec_session+1 # 1-indexing.
#     143 # sessdict = mkl.getSessionsList(animal, datelist=[date])
#     144
#     145 # print("ALL SESSIONS: ")
#     146 # print(sessdict)
# --> 148 SN = load_session_helper(DATE, dataset_beh_expt, rec_session, animal, expt,
#     149     MINIMAL_LOADING=MINIMAL_LOADING,
#     150     units_metadat_fail_if_no_exist=units_metadat_fail_if_no_exist,
#     151     spikes_version=spikes_version)
#     152 SNlist.append(SN)
#     153 print("Extracted successfully for session: ", rec_session)
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:253, in load_session_helper(DATE, dataset_beh_expt, rec_session, animal, expt, do_all_copy_to_local, extract_spiketrain_elephant, DEBUG_TIMING, MINIMAL_LOADING, BAREBONES_LOADING, ACTUALLY_BAREBONES_LOADING, units_metadat_fail_if_no_exist, do_if_spikes_incomplete, spikes_version)
#     235 # # Hard code sessions where multiple sec sessions to a single beh session, this leads to
#     236 # # error where the rec sessions doesnt know which beh trial to start at.
#     237 # if animal=="Pancho" and int(DATE)==221024 and rec_session==1:
#    (...)
#     250 #     print(sessdict[DATE])
#     251 #     assert False
#     252 try:
# --> 253     SN = Session(DATE, beh_expt_list, beh_sess_list, beh_trial_map_list,
#     254         animal =animal,
#     255         rec_session = rec_session, dataset_beh_expt=dataset_beh_expt,
#     256         extract_spiketrain_elephant=extract_spiketrain_elephant,
#     257         do_all_copy_to_local=do_all_copy_to_local, DEBUG_TIMING=DEBUG_TIMING,
#     258         MINIMAL_LOADING= MINIMAL_LOADING, BAREBONES_LOADING=BAREBONES_LOADING,
#     259         units_metadat_fail_if_no_exist=units_metadat_fail_if_no_exist,
#     260         do_if_spikes_incomplete=do_if_spikes_incomplete,
#     261         ACTUALLY_BAREBONES_LOADING=ACTUALLY_BAREBONES_LOADING,
#     262         spikes_version=spikes_version)
#     263 except DataMisalignError as err:
#     264     if ALLOW_RETRY:
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:539, in Session.__init__(self, datestr, beh_expt_list, beh_sess_list, beh_trial_map_list, sites_garbage, expt, animal, path_base, path_local, rec_session, do_all_copy_to_local, extract_spiketrain_elephant, do_sanity_checks, do_sanity_checks_rawdupl, dataset_beh_expt, DEBUG_TIMING, MINIMAL_LOADING, BAREBONES_LOADING, ACTUALLY_BAREBONES_LOADING, units_metadat_fail_if_no_exist, do_if_spikes_incomplete, spikes_version)
#     536     self._savelocalcached_load()
#     537     ###################
# --> 539     check_dict = self._check_preprocess_status()
#     540     assert check_dict["exists_2"], "you have not yet saved cached files. rerun load_and_preprocess_single_session"
#     542 if MINIMAL_LOADING or FULL_LOADING:
#     543     # Load event timing data
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:853, in Session._check_preprocess_status(self)
#     850 exists_1 = os.path.exists(self.Paths["datall_local"])
#     852 # 2nd preprocessing (caching)
# --> 853 exists_2 = self._savelocalcached_check_done()
#     855 # if you have already done 2nd and deleted 1st, then would be waste of time
#     856 # to do full loading.
#     857 preprocessing_all_complete = not exists_1 and exists_2
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:1594, in Session._savelocalcached_check_done(self, datslice_quick_check)
#    1591         if k not in _CachedTrialsList.keys():
#    1592             return False
# -> 1594 if self._savelocalcached_checksaved_datslice(datslice_quick_check=datslice_quick_check)==False:
#    1595     return False
#    1597 return True
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:1827, in Session._savelocalcached_checksaved_datslice(self, datslice_quick_check)
#    1825 for t in trials:
#    1826     for s in sites:
# -> 1827         exists = self._savelocalcached_loadextract_datslice(t, s, only_check_if_exists=True)
#    1828         if not exists:
#    1829             return False
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/session.py:1775, in Session._savelocalcached_loadextract_datslice(self, trial, site, only_check_if_exists)
#    1764 """
#    1765 Load a specific data slice (trial x site) from disk.
#    1766 PARAMS:
#    (...)
#    1771 -- if doesnt exist, then returns None
#    1772 """
#    1773 import os
# -> 1775 if (trial, site) in self._CachedDatSlice.keys():
#    1776     # 1. Then return already extracted
#    1777     return self._CachedDatSlice[(trial, site)]
#    1778 else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### OR load a presaved DFallpa

# %%
import pandas as pd
path = "/home/kgg/Desktop/neuralmonkey/neuralmonkey/notebooks_tutorials/dfallpa_Diego_230630.pkl"
DFallpa = pd.read_pickle(path)

# %%
DFallpa
# Out:
#    which_level  event   bregion        twind  \
# 0         flex  fixon      M1_m  (-0.6, 0.6)
# 1         flex  fixon      M1_l  (-0.6, 0.6)
# 2         flex  fixon     PMv_l  (-0.6, 0.6)
# 3         flex  fixon     PMv_m  (-0.6, 0.6)
# 4         flex  fixon     PMd_p  (-0.6, 0.6)
# 5         flex  fixon     PMd_a  (-0.6, 0.6)
# 6         flex  fixon   dlPFC_a  (-0.6, 0.6)
# 7         flex  fixon   vlPFC_p  (-0.6, 0.6)
# 8         flex  fixon   vlPFC_a  (-0.6, 0.6)
# 9         flex  fixon      FP_p  (-0.6, 0.6)
# 10        flex  fixon      FP_a  (-0.6, 0.6)
# 11        flex  fixon     SMA_p  (-0.6, 0.6)
# 12        flex  fixon     SMA_a  (-0.6, 0.6)
# 13        flex  fixon  preSMA_p  (-0.6, 0.6)
# 14        flex  fixon  preSMA_a  (-0.6, 0.6)
#
#                                                    pa       pa_x_shape
# 0   <neuralmonkey.classes.population.PopAnal objec...  (31, 2528, 100)
# 1   <neuralmonkey.classes.population.PopAnal objec...  (24, 2528, 100)
# 2   <neuralmonkey.classes.population.PopAnal objec...  (32, 2528, 100)
# 3   <neuralmonkey.classes.population.PopAnal objec...  (30, 2528, 100)
# 4   <neuralmonkey.classes.population.PopAnal objec...  (25, 2528, 100)
# 5   <neuralmonkey.classes.population.PopAnal objec...  (18, 2528, 100)
# 6   <neuralmonkey.classes.population.PopAnal objec...  (30, 2528, 100)
# 7   <neuralmonkey.classes.population.PopAnal objec...  (31, 2528, 100)
# 8   <neuralmonkey.classes.population.PopAnal objec...  (24, 2528, 100)
# 9   <neuralmonkey.classes.population.PopAnal objec...  (24, 2528, 100)
# 10  <neuralmonkey.classes.population.PopAnal objec...  (32, 2528, 100)
# 11  <neuralmonkey.classes.population.PopAnal objec...  (32, 2528, 100)
# 12  <neuralmonkey.classes.population.PopAnal objec...  (29, 2528, 100)
# 13  <neuralmonkey.classes.population.PopAnal objec...  (27, 2528, 100)
# 14  <neuralmonkey.classes.population.PopAnal objec...  (29, 2528, 100)

# %% [markdown]
# ### Do normalization of activity, if not already done

# %%
# from neuralmonkey.classes.population_mult import po
path_to_save_example_fr_normalization = None
fr_normalization_method = "each_time_bin"

if fr_normalization_method is not None:
    if fr_normalization_method=="each_time_bin":
        # Then demean in each time bin indepednently
        subtract_mean_at_each_timepoint = True
        subtract_mean_across_time_and_trial = False
    elif fr_normalization_method=="across_time_bins":
        # ALl time bins subtract the same scalar --> maintains temporal moudlation.
        subtract_mean_at_each_timepoint = False
        subtract_mean_across_time_and_trial = True
    else:
        print(fr_normalization_method)
        assert False

    from neuralmonkey.analyses.state_space_good import popanal_preprocess_scalar_normalization
    list_panorm = []

    for i, pa in enumerate(DFallpa["pa"].tolist()):
        if path_to_save_example_fr_normalization is not None and i==0:
            plot_example_chan_number = pa.Chans[0]
            if which_level=="trial":
                plot_example_split_var_string = "seqc_0_shape"
            elif which_level=="stroke":
                plot_example_split_var_string = "shape"
            else:
                plot_example_split_var_string = q_params["effect_vars"][0]
        else:
            plot_example_chan_number = None
            plot_example_split_var_string = None
        PAnorm, PAscal, PAscalagg, fig, axes, groupdict = popanal_preprocess_scalar_normalization(pa, None,
                                                                                          DO_AGG_TRIALS=False,
                                                                                          plot_example_chan_number=plot_example_chan_number,
                                                                                            plot_example_split_var_string = plot_example_split_var_string,
                                                                                          subtract_mean_at_each_timepoint=subtract_mean_at_each_timepoint,
                                                                                          subtract_mean_across_time_and_trial=subtract_mean_across_time_and_trial)
        if path_to_save_example_fr_normalization is not None and i==0:
            savefig(fig, path_to_save_example_fr_normalization)
        list_panorm.append(PAnorm)
    DFallpa["pa"] = list_panorm

# %% [markdown]
# # Scripts to do dim reduction and plot variety of state space plots

# %%
SAVEDIR_ANALYSIS = "/tmp/Diego_230630"

# %% [markdown]
# ### Plot scalar values (time-mean within twindow)

# %%
from neuralmonkey.analyses.state_space_good import trajgood_construct_df_from_raw, trajgood_plot_colorby_splotby, trajgood_plot_colorby_splotby_scalar
from pythonlib.tools.plottools import savefig
from pythonlib.globals import PATH_ANALYSIS_OUTCOMES
import matplotlib.pyplot as plt
import os
from neuralmonkey.analyses.state_space_good import dimredgood_nonlinear_embed_data

### USER PARAMS
tbin_dur = 0.1
tbin_slide = 0.1
umap_n_neighbors = 45
pca_frac_var_keep = 0.8
n_min_per_levo= 5
list_twind_overall = [
    [-0.3, 0.0],
    [0.0, 0.3]
]
# METHOD = "umap"
METHOD = "umap"
list_var_color_var_subplot = [
    ["seqc_0_shape", ("shape-macrosaccade-index", "seqc_0_loc", "shape-fixation", "loc-fixation", "task_kind")],
    ["shape-fixation", ("shape-macrosaccade-index", "loc-fixation", "seqc_0_shape", "seqc_0_loc_on_clust", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "seqc_0_shape", "loc-fixation", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "seqc_0_shape", "seqc_0_loc_on_clust", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "shape-fixation", "loc-fixation", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "shape-fixation", "seqc_0_loc_on_clust", "task_kind")],
]

LIST_DIMS = [(0,1)]

### HARD PARAMS
reshape_method = "trials_x_chanstimes"

for i, row in DFallpa.iterrows():
    pa = row["pa"]
    br = row["bregion"]
    wl = row["which_level"]
    ev = row["event"]
    tw = row["twind"]

    for twind_overall in list_twind_overall:
        
        ###################### SCALAR DATA
        # Extract data
        X, _, pathis, _ = pa.dataextract_state_space_decode_flex(twind_overall, tbin_dur, tbin_slide, reshape_method,
                                                           pca_reduce=True, pca_frac_var_keep=pca_frac_var_keep)
        dflab = pathis.Xlabels["trials"]
        
        if METHOD=="umap":
            # Embed data
            Xredu, _ = dimredgood_nonlinear_embed_data(X, METHOD=METHOD, n_components=2, umap_n_neighbors=umap_n_neighbors)
        elif METHOD=="pca":
            Xredu = X
        else:
            print(METHOD)
            assert False

        ##### Plot scalars
        savedir = f"{SAVEDIR_ANALYSIS}/scalar/{br}-{ev}-twind={'_'.join([str(t) for t in twind_overall])}-METHOD={METHOD}"
        print(savedir)
        os.makedirs(savedir, exist_ok=True)

        for var_color, var_subplot in list_var_color_var_subplot:
            from neuralmonkey.analyses.state_space_good import trajgood_plot_colorby_splotby_scalar_WRAPPER
            trajgood_plot_colorby_splotby_scalar_WRAPPER(Xredu, dflab, var_color, savedir,
                                     vars_subplot=var_subplot, list_dims=LIST_DIMS, n_min_per_levo=n_min_per_levo)
        plt.close("all")
# Out:
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/M1_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_l-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMv_m-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/PMd_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/dlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/vlPFC_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/FP_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# ...
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/SMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_p-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=-0.3_0.0-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# UMAP, Using this n_neighbors: 45 , nsamp = 2528
# /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# Saving ...  /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(0, 1).pdf
# fig: /tmp/Diego_230630/scalar/preSMA_a-fixon-twind=0.0_0.3-METHOD=umap/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc_on_clust|task_kind-dims=(0, 1).pdf

# %% [markdown]
# ### Plot trajectories (within time window)

# %%
from neuralmonkey.analyses.state_space_good import trajgood_construct_df_from_raw, trajgood_plot_colorby_splotby, trajgood_plot_colorby_splotby_scalar
from pythonlib.tools.plottools import savefig
from pythonlib.globals import PATH_ANALYSIS_OUTCOMES
import os
from neuralmonkey.analyses.state_space_good import dimredgood_nonlinear_embed_data
import matplotlib.pyplot as plt

### USER PARAMS
tbin_dur = 0.1
tbin_slide = 0.1
umap_n_neighbors = 45
pca_frac_var_keep = 0.8
n_min_per_levo= 5
list_twind_overall = [
    [0.2, 0.6]
]
# METHOD = "umap"
METHOD = "pca"
list_var_color_var_subplot = [
    ["seqc_0_shape", ("seqc_0_loc", "task_kind")],
    ["seqc_0_loc", ("seqc_0_shape", "task_kind")],
    [("seqc_0_loc", "seqc_0_shape"), ("epoch", "task_kind")],
]
LIST_DIMS = [(0,1)]

### HARD PARAMS
reshape_method = "chans_x_trials_x_times"


for i, row in DFallpa.iterrows():
    pa = row["pa"]
    br = row["bregion"]
    wl = row["which_level"]
    ev = row["event"]
    tw = row["twind"]

    for twind_overall in list_twind_overall:
        
        ###################### TRAJECTORY DATA
        from neuralmonkey.analyses.state_space_good import trajgood_construct_df_from_raw, trajgood_plot_colorby_splotby
        from neuralmonkey.classes.population_mult import extract_single_pa
        twind_overall_traj = [-0.2, 0.6]
        tbin_dur = 0.05
        X, PApca, PAslice, pca = pa.dataextract_state_space_decode_flex(twind_overall_traj, tbin_dur=tbin_dur, pca_reduce=True)
        
        if METHOD=="pca":
            Xredu = X
        else:
            print(METHOD)
            assert False, "code it"
            
        savedir = f"{SAVEDIR_ANALYSIS}/trajectories/{br}-{ev}-twind={'_'.join([str(t) for t in twind_overall_traj])}-METHOD=pca"
        print(savedir)
        os.makedirs(savedir, exist_ok=True)
        
        for var_color, var_subplot in list_var_color_var_subplot:
            for dims in LIST_DIMS:
                # 1) Construct dataframe
                if isinstance(var_color, (list, tuple)):
                    grpvars = list(var_color) + list(var_subplot)
                else:
                    grpvars = [var_color] + list(var_subplot)
                    
                labels = PApca.Xlabels["trials"].loc[:, grpvars] 
                labelvars = grpvars
                df = trajgood_construct_df_from_raw(X, PApca.Times, labels, labelvars)
                
                # 2) Plot
                # dims = (0,1) # pairs of dimensions to plot
                times_to_mark = [0.] # you can mark specific times on the plot. here marks the 0. sec mark.
                times_to_mark_markers = ["d"] # mark with a diamond ("d")
                time_bin_size = 0.05 # to make plot easier to visaulize, you can bin in time.
                
                fig, axes = trajgood_plot_colorby_splotby(df, var_color, var_subplot, dims, "traj", mean_over_trials=True,
                                              times_to_mark = times_to_mark, times_to_mark_markers = times_to_mark_markers,
                                              time_bin_size=time_bin_size)        
                
                path = f"{savedir}/color={var_color}-sub={var_subplot}-dims={dims[0], dims[1]}.pdf"
                print("Saving ... ", path)
                savefig(fig, path)
                
                plt.close("all")
