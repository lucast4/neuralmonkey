# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Extracting a dataset preprocessed and ready for decoding (and other population analyses)

# %% [markdown]
# ### Load a presaved DFallpa

# %%
import pandas as pd
import os

animal = "Diego"
date = 230630

path = f"/home/kgg/Desktop/eyetracking_analyses/{animal}-{date}/dfallpa.pkl"
DFallpa = pd.read_pickle(path)

# %%
DFallpa
# Out:
#    which_level              event   bregion        twind  \
# 0         flex  fixon_preparation      M1_m  (-0.4, 0.4)
# 1         flex  fixon_preparation      M1_l  (-0.4, 0.4)
# 2         flex  fixon_preparation     PMv_l  (-0.4, 0.4)
# 3         flex  fixon_preparation     PMv_m  (-0.4, 0.4)
# 4         flex  fixon_preparation     PMd_p  (-0.4, 0.4)
# 5         flex  fixon_preparation     PMd_a  (-0.4, 0.4)
# 6         flex  fixon_preparation   dlPFC_a  (-0.4, 0.4)
# 7         flex  fixon_preparation   vlPFC_p  (-0.4, 0.4)
# 8         flex  fixon_preparation   vlPFC_a  (-0.4, 0.4)
# 9         flex  fixon_preparation      FP_p  (-0.4, 0.4)
# 10        flex  fixon_preparation      FP_a  (-0.4, 0.4)
# 11        flex  fixon_preparation     SMA_p  (-0.4, 0.4)
# 12        flex  fixon_preparation     SMA_a  (-0.4, 0.4)
# 13        flex  fixon_preparation  preSMA_p  (-0.4, 0.4)
# 14        flex  fixon_preparation  preSMA_a  (-0.4, 0.4)
#
#                                                    pa      pa_x_shape
# 0   <neuralmonkey.classes.population.PopAnal objec...  (23, 2381, 80)
# 1   <neuralmonkey.classes.population.PopAnal objec...  (18, 2381, 80)
# 2   <neuralmonkey.classes.population.PopAnal objec...  (43, 2381, 80)
# 3   <neuralmonkey.classes.population.PopAnal objec...  (36, 2381, 80)
# 4   <neuralmonkey.classes.population.PopAnal objec...  (24, 2381, 80)
# 5   <neuralmonkey.classes.population.PopAnal objec...  (19, 2381, 80)
# 6   <neuralmonkey.classes.population.PopAnal objec...  (27, 2381, 80)
# 7   <neuralmonkey.classes.population.PopAnal objec...  (32, 2381, 80)
# 8   <neuralmonkey.classes.population.PopAnal objec...  (18, 2381, 80)
# 9   <neuralmonkey.classes.population.PopAnal objec...  (17, 2381, 80)
# 10  <neuralmonkey.classes.population.PopAnal objec...  (22, 2381, 80)
# 11  <neuralmonkey.classes.population.PopAnal objec...  (24, 2381, 80)
# 12  <neuralmonkey.classes.population.PopAnal objec...  (25, 2381, 80)
# 13  <neuralmonkey.classes.population.PopAnal objec...  (29, 2381, 80)
# 14  <neuralmonkey.classes.population.PopAnal objec...  (27, 2381, 80)

# %% [markdown]
# ### OR, extract DFallpa using this helper function

# %%
from neuralmonkey.classes.population_mult import dfallpa_extraction_load_wrapper
animal = "Diego"
date = 230630
question = "PIG_BASE_trial" # holds variety of prepropoessing steps to clean data, specificalyl for PIG data.
list_time_windows = [(-0.6, 0.6)] # to slice data including just within this time window (realtive to events)
events_keep = ["00_fixon"]
combine_into_larger_areas = False
which_level = "saccade_fix_on"
SPIKES_VERSION = "tdt"
DFallpa = dfallpa_extraction_load_wrapper(animal, date, question, list_time_windows,
                                    which_level=which_level,
                                    events_keep = events_keep,
                                    combine_into_larger_areas=combine_into_larger_areas,
                                    HACK_RENAME_SHAPES=False,
                                          SPIKES_VERSION=SPIKES_VERSION)

# %%
DFallpa

# %% [markdown]
# ### Do normalization of activity, if not already done

# %%
# from neuralmonkey.classes.population_mult import po
path_to_save_example_fr_normalization = None
fr_normalization_method = "each_time_bin"

if fr_normalization_method is not None:
    if fr_normalization_method=="each_time_bin":
        # Then demean in each time bin indepednently
        subtract_mean_at_each_timepoint = True
        subtract_mean_across_time_and_trial = False
    elif fr_normalization_method=="across_time_bins":
        # ALl time bins subtract the same scalar --> maintains temporal moudlation.
        subtract_mean_at_each_timepoint = False
        subtract_mean_across_time_and_trial = True
    else:
        print(fr_normalization_method)
        assert False

    from neuralmonkey.analyses.state_space_good import popanal_preprocess_scalar_normalization
    list_panorm = []

    for i, pa in enumerate(DFallpa["pa"].tolist()):
        if path_to_save_example_fr_normalization is not None and i==0:
            plot_example_chan_number = pa.Chans[0]
            if which_level=="trial":
                plot_example_split_var_string = "seqc_0_shape"
            elif which_level=="stroke":
                plot_example_split_var_string = "shape"
            else:
                plot_example_split_var_string = q_params["effect_vars"][0]
        else:
            plot_example_chan_number = None
            plot_example_split_var_string = None
        PAnorm, PAscal, PAscalagg, fig, axes, groupdict = popanal_preprocess_scalar_normalization(pa, None,
                                                                                          DO_AGG_TRIALS=False,
                                                                                          plot_example_chan_number=plot_example_chan_number,
                                                                                            plot_example_split_var_string = plot_example_split_var_string,
                                                                                          subtract_mean_at_each_timepoint=subtract_mean_at_each_timepoint,
                                                                                          subtract_mean_across_time_and_trial=subtract_mean_across_time_and_trial)
        if path_to_save_example_fr_normalization is not None and i==0:
            savefig(fig, path_to_save_example_fr_normalization)
        list_panorm.append(PAnorm)
    DFallpa["pa"] = list_panorm

# %% [markdown]
# # Scripts to do dim reduction and plot variety of state space plots

# %%
SAVEDIR_ANALYSIS = f"/home/kgg/Desktop/eyetracking_analyses/SUBSPACES/{animal}-{date}"
os.makedirs(SAVEDIR_ANALYSIS, exist_ok=True)

# %% [markdown]
# ### Plot scalar values (time-mean within twindow)

# %%
from neuralmonkey.analyses.state_space_good import trajgood_construct_df_from_raw, trajgood_plot_colorby_splotby, trajgood_plot_colorby_splotby_scalar
from pythonlib.tools.plottools import savefig
from pythonlib.globals import PATH_ANALYSIS_OUTCOMES
import matplotlib.pyplot as plt
import os
from neuralmonkey.analyses.state_space_good import dimredgood_nonlinear_embed_data

### USER PARAMS
tbin_dur = 0.1
tbin_slide = 0.1
umap_n_neighbors = 45
pca_frac_var_keep = 0.8
n_min_per_levo= 5
list_twind_overall = [
    [-0.2, 0.0],
    [0.0, 0.2]
]
# METHOD = "umap"
METHOD = "pca"
list_var_color_var_subplot = [
    ["seqc_0_shape", ("shape-macrosaccade-index", "seqc_0_loc", "shape-fixation", "task_kind")],
    ["seqc_0_shape", ("is-first-macrosaccade", "seqc_0_loc", "shape-fixation", "task_kind")],
    ["shape-fixation", ("shape-macrosaccade-index", "loc-fixation", "seqc_0_shape", "task_kind")],
    ["shape-fixation", ("is-first-macrosaccade", "loc-fixation", "seqc_0_shape", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "seqc_0_shape", "loc-fixation", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "seqc_0_shape", "seqc_0_loc", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "shape-fixation", "loc-fixation", "task_kind")],
    ["is-fixated-on-seqc0shape", ("shape-macrosaccade-index", "shape-fixation", "seqc_0_loc", "task_kind")],
]

#LIST_DIMS = [(0,1)]
LIST_DIMS = [(1,2)]

### HARD PARAMS
reshape_method = "trials_x_chanstimes"

for i, row in DFallpa.iterrows():
    pa = row["pa"]
    br = row["bregion"]
    wl = row["which_level"]
    ev = row["event"]
    tw = row["twind"]

    for twind_overall in list_twind_overall:
        
        ###################### SCALAR DATA
        # Extract data
        X, _, pathis, _, _ = pa.dataextract_state_space_decode_flex(twind_overall, tbin_dur, tbin_slide, reshape_method,
                                                           pca_reduce=True, pca_frac_var_keep=pca_frac_var_keep)
        dflab = pathis.Xlabels["trials"]
        
        if METHOD=="umap":
            # Embed data
            Xredu, _ = dimredgood_nonlinear_embed_data(X, METHOD=METHOD, n_components=2, umap_n_neighbors=umap_n_neighbors)
        elif METHOD=="pca":
            Xredu = X
        else:
            print(METHOD)
            assert False

        ##### Plot scalars
        savedir = f"{SAVEDIR_ANALYSIS}/raw_pca_plots/{br}-{ev}-twind={'_'.join([str(t) for t in twind_overall])}-METHOD={METHOD}"
        print(savedir)
        os.makedirs(savedir, exist_ok=True)

        for var_color, var_subplot in list_var_color_var_subplot:
            from neuralmonkey.analyses.state_space_good import trajgood_plot_colorby_splotby_scalar_WRAPPER
            trajgood_plot_colorby_splotby_scalar_WRAPPER(Xredu, dflab, var_color, savedir,
                                     vars_subplot=var_subplot, list_dims=LIST_DIMS, n_min_per_levo=n_min_per_levo)
        plt.close("all")
# Out:
# Running PCA
# cumvar 0.8 0.01
# /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=seqc_0_shape-sub=shape-macrosaccade-index|seqc_0_loc|shape-fixation|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=seqc_0_shape-sub=is-first-macrosaccade|seqc_0_loc|shape-fixation|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=seqc_0_shape-sub=is-first-macrosaccade|seqc_0_loc|shape-fixation|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=shape-fixation-sub=shape-macrosaccade-index|loc-fixation|seqc_0_shape|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=shape-fixation-sub=is-first-macrosaccade|loc-fixation|seqc_0_shape|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=shape-fixation-sub=is-first-macrosaccade|loc-fixation|seqc_0_shape|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|loc-fixation|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|seqc_0_shape|seqc_0_loc|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|loc-fixation|task_kind-dims=(1, 2).pdf
# fig: /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc|task_kind-dims=(1, 2).pdf
# Saving ...  /home/kgg/Desktop/eyetracking_analyses/SUBSPACES/Diego-230630/scalar_plots/M1_m-fixon_preparation-twind=-0.3_0.0-METHOD=pca/color=is-fixated-on-seqc0shape-sub=shape-macrosaccade-index|shape-fixation|seqc_0_loc|task_kind-dims=(1, 2).pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 68
#      66 for var_color, var_subplot in list_var_color_var_subplot:
#      67     from neuralmonkey.analyses.state_space_good import trajgood_plot_colorby_splotby_scalar_WRAPPER
# ---> 68     trajgood_plot_colorby_splotby_scalar_WRAPPER(Xredu, dflab, var_color, savedir,
#      69                              vars_subplot=var_subplot, list_dims=LIST_DIMS, n_min_per_levo=n_min_per_levo)
#      70 plt.close("all")
#
# File ~/Desktop/neuralmonkey/neuralmonkey/analyses/state_space_good.py:1538, in trajgood_plot_colorby_splotby_scalar_WRAPPER(X, dflab, var_color, savedir, vars_subplot, list_dims, STROKES_BEH, STROKES_TASK, n_min_per_levo, overlay_mean, overlay_mean_var_color, connect_means_with_line, connect_means_with_line_levels, SIZE, alpha, skip_subplots_lack_mult_colors, save_suffix, plot_3D)
#    1536 if fig is not None:
#    1537     print("Saving ... ", path)
# -> 1538     savefig(fig, path)
#    1540 # With drawings
#    1541 if STROKES_BEH is not None or STROKES_TASK is not None:
#
# File ~/Desktop/pythonlib/pythonlib/tools/plottools.py:337, in savefig(fig, path)
#     334 def savefig(fig, path):
#     335     """ helper to save without clipping axis labels
#     336     """
# --> 337     fig.savefig(path, bbox_inches="tight")
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340 if bbox_inches:
#    2341     if bbox_inches == "tight":
# -> 2342         bbox_inches = self.figure.get_tightbbox(
#    2343             renderer, bbox_extra_artists=bbox_extra_artists)
#    2344         if pad_inches is None:
#    2345             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/figure.py:1731, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1728     artists = bbox_extra_artists
#    1730 for a in artists:
# -> 1731     bbox = a.get_tightbbox(renderer)
#    1732     if bbox is not None:
#    1733         bb.append(bbox)
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/axes/_base.py:4390, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4388         if ba:
#    4389             bb.append(ba)
# -> 4390 self._update_title_position(renderer)
#    4391 axbbox = self.get_window_extent(renderer)
#    4392 bb.append(axbbox)
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/axes/_base.py:2965, in _AxesBase._update_title_position(self, renderer)
#    2962 bb = None
#    2963 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2964         or ax.xaxis.get_label_position() == 'top'):
# -> 2965     bb = ax.xaxis.get_tightbbox(renderer)
#    2966 if bb is None:
#    2967     if 'outline' in ax.spines:
#    2968         # Special case for colorbars:
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/axis.py:1320, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1317     renderer = self.figure._get_renderer()
#    1318 ticks_to_draw = self._update_ticks()
# -> 1320 self._update_label_position(renderer)
#    1322 # go back to just this axis's tick labels
#    1323 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/axis.py:2314, in XAxis._update_label_position(self, renderer)
#    2312 try:
#    2313     spine = self.axes.spines['bottom']
# -> 2314     spinebbox = spine.get_window_extent()
#    2315 except KeyError:
#    2316     # use Axes if spine doesn't exist
#    2317     spinebbox = self.axes.bbox
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/spines.py:158, in Spine.get_window_extent(self, renderer)
#     156     return bb
#     157 bboxes = [bb]
# --> 158 drawn_ticks = self.axis._update_ticks()
#     160 major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#     161 minor_tick = next(iter({*drawn_ticks} & {*self.axis.minorTicks}), None)
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/axis.py:1265, in Axis._update_ticks(self)
#    1263     tick.set_label1(label)
#    1264     tick.set_label2(label)
# -> 1265 minor_locs = self.get_minorticklocs()
#    1266 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1267 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File ~/anaconda3/envs/ppmonkey/lib/python3.10/site-packages/matplotlib/axis.py:1490, in Axis.get_minorticklocs(self)
#    1488 tr_minor_locs = transform.transform(minor_locs)
#    1489 tr_major_locs = transform.transform(major_locs)
# -> 1490 lo, hi = sorted(transform.transform(self.get_view_interval()))
#    1491 # Use the transformed view limits as scale.  1e-5 is the default
#    1492 # rtol for np.isclose.
#    1493 tol = (hi - lo) * 1e-5
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x7f3349360ca0> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x7f33443b1ab0> (for post_execute):
# KeyboardInterrupt

# %% [markdown]
# ### Plot trajectories (within time window)

# %%
from neuralmonkey.analyses.state_space_good import trajgood_construct_df_from_raw, trajgood_plot_colorby_splotby, trajgood_plot_colorby_splotby_scalar
from pythonlib.tools.plottools import savefig
from pythonlib.globals import PATH_ANALYSIS_OUTCOMES
import os
from neuralmonkey.analyses.state_space_good import dimredgood_nonlinear_embed_data
import matplotlib.pyplot as plt

### USER PARAMS
tbin_dur = 0.1
tbin_slide = 0.1
umap_n_neighbors = 45
pca_frac_var_keep = 0.8
n_min_per_levo= 5
list_twind_overall = [
    [0.2, 0.6]
]
# METHOD = "umap"
METHOD = "pca"
list_var_color_var_subplot = [
    ["seqc_0_shape", ("seqc_0_loc", "task_kind")],
    ["seqc_0_loc", ("seqc_0_shape", "task_kind")],
    [("seqc_0_loc", "seqc_0_shape"), ("epoch", "task_kind")],
]
LIST_DIMS = [(0,1)]

### HARD PARAMS
reshape_method = "chans_x_trials_x_times"


for i, row in DFallpa.iterrows():
    pa = row["pa"]
    br = row["bregion"]
    wl = row["which_level"]
    ev = row["event"]
    tw = row["twind"]

    for twind_overall in list_twind_overall:
        
        ###################### TRAJECTORY DATA
        from neuralmonkey.analyses.state_space_good import trajgood_construct_df_from_raw, trajgood_plot_colorby_splotby
        from neuralmonkey.classes.population_mult import extract_single_pa
        twind_overall_traj = [-0.2, 0.6]
        tbin_dur = 0.05
        X, PApca, PAslice, pca = pa.dataextract_state_space_decode_flex(twind_overall_traj, tbin_dur=tbin_dur, pca_reduce=True)
        
        if METHOD=="pca":
            Xredu = X
        else:
            print(METHOD)
            assert False, "code it"
            
        savedir = f"{SAVEDIR_ANALYSIS}/trajectories/{br}-{ev}-twind={'_'.join([str(t) for t in twind_overall_traj])}-METHOD=pca"
        print(savedir)
        os.makedirs(savedir, exist_ok=True)
        
        for var_color, var_subplot in list_var_color_var_subplot:
            for dims in LIST_DIMS:
                # 1) Construct dataframe
                if isinstance(var_color, (list, tuple)):
                    grpvars = list(var_color) + list(var_subplot)
                else:
                    grpvars = [var_color] + list(var_subplot)
                    
                labels = PApca.Xlabels["trials"].loc[:, grpvars] 
                labelvars = grpvars
                df = trajgood_construct_df_from_raw(X, PApca.Times, labels, labelvars)
                
                # 2) Plot
                # dims = (0,1) # pairs of dimensions to plot
                times_to_mark = [0.] # you can mark specific times on the plot. here marks the 0. sec mark.
                times_to_mark_markers = ["d"] # mark with a diamond ("d")
                time_bin_size = 0.05 # to make plot easier to visaulize, you can bin in time.
                
                fig, axes = trajgood_plot_colorby_splotby(df, var_color, var_subplot, dims, "traj", mean_over_trials=True,
                                              times_to_mark = times_to_mark, times_to_mark_markers = times_to_mark_markers,
                                              time_bin_size=time_bin_size)        
                
                path = f"{savedir}/color={var_color}-sub={var_subplot}-dims={dims[0], dims[1]}.pdf"
                print("Saving ... ", path)
                savefig(fig, path)
                
                plt.close("all")
