# %%
"""
Focusing on things that were not done in v1.

"""
# Out:
# '\nFocusing on things that were not done in v1.\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

from neuralmonkey.classes.session import load_mult_session_helper
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#%matplotlib inline

# %%
# load all sessions for Pancho on 221020
MS = load_mult_session_helper(221020, 'Pancho')
# Out:
# Searching using this string:
# /home/kgg/mnt/Freiwald/ltian/recordings/*Pancho*/*221020*/**
# Found this many paths:
# 2
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238
# session:  0
# Searching using this string:
# /home/kgg/mnt/Freiwald/ltian/recordings/*Pancho*/*221020*/**
# Found this many paths:
# 2
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238
# Beh Sessions hand netered (mapping: rec sess --> beh sess):  [2, 3]
# Beh Sessions that exist on this date:  {221020: [(2, 'dirshapecolor1b'), (3, 'dirshapecolor1b')]}
# ------------------------------
# Loading this neural session: 0
# Loading these beh expts: ['dirshapecolor1b']
# Loading these beh sessions: [2]
# Using this beh_trial_map_list: [(1, 0)]
# Searching using this string:
# /home/kgg/mnt/Freiwald/ltian/recordings/*Pancho*/*221020*/**
# Found this many paths:
# 2
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238
# {'filename_components_hyphened': ['Pancho', '221020', '133436'], 'basedirs': ['/home/kgg/mnt/Freiwald/ltian/recordings/Pancho', '/home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020'], 'basedirs_filenames': ['221020', 'Pancho-221020-133436'], 'filename_final_ext': 'Pancho-221020-133436', 'filename_final_noext': 'Pancho-221020-133436'}
# FOund this path for spikes:  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436/spikes_tdt_quick-3.5
# == PATHS for this expt:
# raws  --  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436
# tank  --  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436/Pancho-221020-133436
# spikes  --  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436/spikes_tdt_quick-3.5
# final_dir_name  --  Pancho-221020-133436
# time  --  133436
# pathbase_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436
# tank_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/data_tank.pkl
# spikes_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/data_spikes.pkl
# datall_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/data_datall.pkl
# events_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/events_photodiode.pkl
# mapper_st2dat_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/mapper_st2dat.pkl
# figs_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/figs
# metadata_units  --  /home/kgg/Desktop/neuralmonkey/neuralmonkey/metadat/units
# cached_dir  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-133436/cached
# Found! metada path :  /home/kgg/Desktop/neuralmonkey/neuralmonkey/metadat/units/221020.yaml
# Starting lengths:
# 185
# 211
# Union length
# 220
# updating self.SitesDirty with:  ('sites_garbage', 'sites_error_spikes', 'sites_low_spk_magn')
# [_sitesdirty_update] skipping! since did not find:  sites_error_spikes
# Printing whether spikes gotten (o) or not (-) because of spike peak to trough
# -  1 60.49959030151367
# o  2 78.58122634887695
# o  3 71.88599853515625
# -  4 52.06213035583497
# -  5 68.32661743164063
# -  6 64.94697570800781
# o  7 111.0613525390625
# -  8 65.94877395629882
# o  9 230.70795593261718
# o  10 83.93440551757813
# o  11 125.0903823852539
# -  12 59.789200973510745
# o  13 181.8536544799805
# o  14 77.747859954834
# o  15 126.31007385253922
# o  16 78.76310501098634
# o  17 70.43129119873046
# -  18 60.52934684753418
# o  19 89.83150100708008
# -  20 42.86078033447266
# o  21 81.3136688232422
# o  22 89.24597702026368
# -  23 46.91471366882325
# -  24 62.92217178344727
# -  25 68.30422592163086
# o  26 290.8430114746094
# o  27 92.99994735717773
# o  28 78.46160736083985
# o  29 210.0858901977539
# o  30 90.6371192932129
# o  31 156.38555603027345
# o  32 73.41127853393554
# o  33 78.6948455810547
# o  34 81.02694473266602
# -  35 41.71623992919922
# o  36 83.6742919921875
# -  37 64.98637771606445
# o  38 158.2415496826172
# -  39 63.643476486206055
# o  40 95.0186264038086
# -  41 66.10351028442383
# o  42 82.99231109619141
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238
# Beh Sessions hand netered (mapping: rec sess --> beh sess):  [2, 3]
# Beh Sessions that exist on this date:  {221020: [(2, 'dirshapecolor1b'), (3, 'dirshapecolor1b')]}
# ------------------------------
# Loading this neural session: 1
# Loading these beh expts: ['dirshapecolor1b']
# Loading these beh sessions: [3]
# Using this beh_trial_map_list: [(1, 0)]
# Searching using this string:
# /home/kgg/mnt/Freiwald/ltian/recordings/*Pancho*/*221020*/**
# Found this many paths:
# 2
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-133436
# ---
# /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238
# {'filename_components_hyphened': ['Pancho', '221020', '161238'], 'basedirs': ['/home/kgg/mnt/Freiwald/ltian/recordings/Pancho', '/home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020'], 'basedirs_filenames': ['221020', 'Pancho-221020-161238'], 'filename_final_ext': 'Pancho-221020-161238', 'filename_final_noext': 'Pancho-221020-161238'}
# FOund this path for spikes:  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238/spikes_tdt_quick-3.5
# == PATHS for this expt:
# raws  --  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238
# tank  --  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238/Pancho-221020-161238
# spikes  --  /home/kgg/mnt/Freiwald/ltian/recordings/Pancho/221020/Pancho-221020-161238/spikes_tdt_quick-3.5
# final_dir_name  --  Pancho-221020-161238
# time  --  161238
# pathbase_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238
# tank_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/data_tank.pkl
# spikes_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/data_spikes.pkl
# datall_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/data_datall.pkl
# events_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/events_photodiode.pkl
# mapper_st2dat_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/mapper_st2dat.pkl
# figs_local  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/figs
# metadata_units  --  /home/kgg/Desktop/neuralmonkey/neuralmonkey/metadat/units
# cached_dir  --  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/cached
# Found! metada path :  /home/kgg/Desktop/neuralmonkey/neuralmonkey/metadat/units/221020.yaml
# Starting lengths:
# 185
# 211
# Union length
# 220
# updating self.SitesDirty with:  ('sites_garbage', 'sites_error_spikes', 'sites_low_spk_magn')
# [_sitesdirty_update] skipping! since did not find:  sites_error_spikes
# Printing whether spikes gotten (o) or not (-) because of spike peak to trough
# -  1 59.87544174194336
# o  2 71.43490829467774
# o  3 74.11155166625977
# -  4 51.83484001159668
# -  5 67.91168975830078
# -  6 62.721047973632814
# o  7 103.02101516723633
# o  8 70.16592178344727
# o  9 230.51370849609376
# o  10 83.12872467041015
# o  11 123.39369049072266
# -  12 60.25550918579102
# o  13 180.58516845703124
# o  14 71.54582214355469
# o  15 168.61119995117207
# o  16 78.90322723388672
# o  17 85.81294631958008
# -  18 64.03630218505859
# o  19 92.54992980957032
# -  20 45.60484848022461
# -  21 69.23218231201173
# o  22 83.0410057067871
# -  23 48.78111724853515
# -  24 62.00285263061524
# -  25 53.89940757751465
# o  26 246.43975372314452
# o  27 96.19383087158204
# o  28 76.1088653564453
# o  29 202.24419250488282
# o  30 77.40046157836915
# o  31 138.72937927246096
# o  32 73.80005798339845
# o  33 79.36588592529297
# o  34 71.9325180053711
# -  35 43.04651031494141
# o  36 80.93816528320312
# -  37 65.06720199584962
# o  38 129.33651580810547
# -  39 62.72526397705078
# o  40 93.64911270141602
# -  41 64.13266906738282
# o  42 77.22839126586915
# o  43 198.06954498291017
# o  44 145.88698120117186
# o  45 996.4759338378907
# -  46 52.863228988647464
# o  47 150.14835205078126
# -  48 41.97841110229492
# o  49 76.45105438232423
# o  50 72.74273147583008
# o  51 98.63881988525391
# -  52 60.61277198791504
# o  53 340.7286010742188
# -  54 60.4719841003418
# o  406 92.01182708740234
# o  407 518.6797180175781
# o  408 96.210400390625
# -  409 50.7888671875
# o  410 126.055778503418
# o  411 98.12856445312501
# o  412 74.73577423095703
# o  413 91.43807830810547
# o  414 159.00125122070318
# o  415 130.13082580566407
# -  416 54.79893035888672
# o  417 101.36833038330079
# -  418 64.64292984008789
# o  419 109.76733169555665
# -  420 59.0703971862793
# -  421 67.64531326293945
# o  422 85.30699691772462
# -  423 67.07557601928711
# -  424 62.854683303833006
# -  425 69.34580383300782
# -  426 50.47331008911133
# -  427 61.20220260620117
# -  428 25.86984157562256
# o  429 71.33556594848633
# -  430 69.09191360473633
# -  431 49.50743713378907
# -  432 45.60574989318848
# o  433 97.18047256469727
# o  434 115.67001190185549
# o  435 155.95215454101563
# o  436 127.83385009765625
# -  437 57.186877822875985
# -  438 50.23661994934082
# o  439 87.35210647583008
# -  440 61.3747859954834
# o  441 124.0721572875977
# -  442 50.45360069274902
# o  443 119.5708724975586
# -  444 40.193899917602536
# o  445 80.93143310546876
# -  446 32.437808227539065
# o  447 84.45361328125
# -  448 27.809246063232422
# o  449 91.28106079101563
# o  450 108.84715118408204
# o  451 79.44926071166994
# o  452 115.36124114990236
# o  453 84.57846450805664
# o  454 73.81371459960938
# o  455 75.85323562622071
# -  456 62.20637588500976
# -  457 69.73522644042968
# -  458 60.282536315917966
# o  459 173.14617614746095
# o  460 93.43121795654297
# o  461 125.70499420166016
# -  462 59.58906211853028
# o  463 74.27914505004884
# o  464 111.02204208374023
# o  465 80.23159484863282
# -  466 44.1486873626709
# o  467 104.00179748535156
# o  468 111.21218719482422
# o  469 152.2602767944336
# -  470 52.85732574462891
# -  471 69.51150817871094
# o  472 85.57113342285157
# o  473 106.31967620849609
# o  474 114.61220703125
# o  475 75.01795883178711
# -  476 49.38324661254883
# o  477 155.03026275634767
# o  478 76.65688629150391
# -  479 61.67750015258789
# o  480 97.4282669067383
# o  481 80.24554977416993
# -  482 33.92056465148926
# o  483 78.15819702148437
# o  484 112.31089782714845
# o  485 214.8375946044922
# o  486 233.06773681640627
# o  487 74.1668312072754
# o  488 116.96527252197266
# o  489 125.69359512329102
# -  490 53.70753898620606
# o  491 81.28567199707031
# -  492 68.74266815185547
# o  493 98.68740463256836
# -  494 68.01201629638672
# o  495 79.97383575439453
# o  496 93.31655654907227
# -  497 66.55422973632812
# o  498 99.92363357543945
# -  499 61.85663528442383
# o  500 137.13247833251953
# -  501 69.6192840576172
# o  502 204.7485580444336
# -  503 67.18977661132813
# o  504 86.18378524780273
# o  505 103.01968231201172
# o  506 71.65923538208008
# -  507 31.097956466674805
# -  508 48.25828819274903
# o  509 95.1972526550293
# -  510 47.036780166625974
# -  511 32.83336982727051
# -  512 50.38900299072266
# == Loading TDT tank
# ** Loading tank data from local (previusly cached)
# == Done
# == Trying to load events data
# Loading this events (pd) locally to:  /data4/Kedar/neural_preprocess/recordings/Pancho/221020/Pancho-221020-161238/events_photodiode.pkl
# == Done
# ** MINIMAL_LOADING, therefore loading previuosly cached data
# Generated self._MapperTrialcode2TrialToTrial!
# Extracted into self.Dat[epoch_orig]
# === CLEANING UP self.Dat (_cleanup_reloading_saved_state) =====
# 0 _behclass_alignsim_compute
# Running D._behclass_tokens_extract_datsegs
# 0 _behclass_tokens_extract_datsegs
# stored in self.Dat[BehClass]
# Extracted successfully for session:  1
# Generated index mappers!

# %% [markdown]
# ### Snippets

# %% [markdown]
# Collects data aligned to instances of a given event. Can then use the Snippets methods to do many things, plotting, analysis, etc.

# %%
from neuralmonkey.classes.snippets import Snippets, extraction_helper

# %%
# Pick out a single session
sn = MS.SessionsList[0]

# %%
# Turn on debug mode, this prunes sites and trials, so below runs faster
DEBUG = True
sn._DEBUG_PRUNE_SITES = DEBUG
sn._DEBUG_PRUNE_TRIALS = DEBUG

# %%
# ****** FOR KEDAR: you would want to modify list_events to something like this:
list_events = ["saccon", "saccoff"]

# %%
# Main code for extracting Snippets (SP)

# == MODIFY THESE:
list_events = ["go"]
list_pre_dur = [-0.5]
list_post_dur = [0.5]

# == IGNORE THESE:
which_level = "flex"
list_features_extraction = []
list_features_get_conjunction = []
trials_prune_just_those_including_events=False

SP = Snippets(sn,
    which_level,
    list_events,
    list_features_extraction,
    list_features_get_conjunction,
    list_pre_dur,
    list_post_dur,
    strokes_only_keep_single=False,
    tasks_only_keep_these=None,
    prune_feature_levels_min_n_trials=None,
    dataset_pruned_for_trial_analysis=None,
    trials_prune_just_those_including_events=trials_prune_just_those_including_events,
    fr_which_version='sqrt',
    NEW_VERSION=True,
    SKIP_DATA_EXTRACTION=False
             )
# Out:
#  == extarcating these sites:  [2, 33, 66, 97, 130, 161, 193, 225, 257, 294, 327, 367, 385, 417, 449, 481]
#
#  == extracting these trials:  [0, 27, 60, 94, 121, 159, 189, 220, 251, 279, 314, 342, 374, 410, 443, 471, 505, 533, 560, 600]
# Extracting smoothed FR for all data...
# Inserting smoothed FR into dataset...
# ** Generated Snippets, (ver flex). Final length of SP.DfScalar: 320
# Starting len:  320
# Removed outliers! new len:  320

# %%
# Inspect the data. 
# Each row represents a single combination of:
# (trial, chan, event). To see that, inspect the output of 

display(SP.DfScalar)

from pythonlib.tools.pandastools import grouping_print_n_samples
grouping_print_n_samples(SP.DfScalar, ["trialcode", "chan", "event_aligned"])
# Out:
#         trialcode  chan event_unique_name event_aligned  \
# 0      221020-2-1     2             00_go         00_go
# 1      221020-2-1    33             00_go         00_go
# 2      221020-2-1    66             00_go         00_go
# 3      221020-2-1    97             00_go         00_go
# 4      221020-2-1   130             00_go         00_go
# ..            ...   ...               ...           ...
# 315  221020-2-601   367             00_go         00_go
# 316  221020-2-601   385             00_go         00_go
# 317  221020-2-601   417             00_go         00_go
# 318  221020-2-601   449             00_go         00_go
# 319  221020-2-601   481             00_go         00_go
#
#                                            spike_times  trial_neural  \
# 0    [-0.48693204521124756, -0.41336788521124745, -...             0
# 1    [-0.35831764521124754, -0.30871508521124724, -...             0
# 2            [-0.308756045211247, 0.12967979478875336]             0
# 3    [-0.4809109252112478, -0.45699028521124774, -0...             0
# 4    [-0.47144916521124713, -0.46317524521124653, -...             0
# ..                                                 ...           ...
# 315  [-0.19179940720823652, -0.03934628720890032, 0...           600
# 316  [-0.48765348720917245, -0.44571044720942155, -...           600
# 317  [-0.48507300720848434, -0.46451108720793854, -...           600
# 318  [-0.47430052720847016, -0.43530660720898595, -...           600
# 319  [0.08746587279165396, 0.21063259279071644, 0.2...           600
#
#      event_time                                              fr_sm  \
# 0      5.199432  [[11.346740799682868, 11.836989504350855, 12.0...
# 1      5.199432  [[9.646250259959345, 8.078632492421304, 6.5072...
# 2      5.199432  [[0.0003995935276705609, 0.001192965913530486,...
# 3      5.199432  [[27.262442194225635, 31.315642205826595, 35.8...
# 4      5.199432  [[42.12101253304793, 40.91670403754879, 39.671...
# ..          ...                                                ...
# 315    3.757983  [[6.049268112978585, 4.566227134725548, 3.2379...
# 316    3.757983  [[40.33169557180256, 38.89758581034813, 37.120...
# 317    3.757983  [[17.425671774279643, 19.05700079228736, 19.79...
# 318    3.757983  [[15.41025196775888, 16.449840880466798, 17.39...
# 319    3.757983  [[0.8153083632678328, 0.4470224043983984, 0.23...
#
#                                            fr_sm_times event  fr_scalar_raw  \
# 0    [[-0.495, -0.4850000000000002, -0.474999999999...    go           39.0
# 1    [[-0.495, -0.4850000000000002, -0.474999999999...    go            6.0
# 2    [[-0.495, -0.4850000000000002, -0.474999999999...    go            2.0
# 3    [[-0.495, -0.4850000000000002, -0.474999999999...    go           65.0
# 4    [[-0.495, -0.4850000000000002, -0.474999999999...    go           37.0
# ..                                                 ...   ...            ...
# 315  [[-0.495, -0.4850000000000002, -0.474999999999...    go            3.0
# 316  [[-0.495, -0.4850000000000002, -0.474999999999...    go           31.0
# 317  [[-0.495, -0.4850000000000002, -0.474999999999...    go           16.0
# 318  [[-0.495, -0.4850000000000002, -0.474999999999...    go           13.0
# 319  [[-0.495, -0.4850000000000002, -0.474999999999...    go            3.0
#
#      fr_scalar                                         fr_sm_sqrt  \
# 0     6.244998  [[3.368492363013885, 3.4404926252429107, 3.472...
# 1     2.449490  [[3.1058413127459272, 2.842293526788059, 2.550...
# 2     1.414214  [[0.019989835608892857, 0.034539338637711144, ...
# 3     8.062258  [[5.221344864517726, 5.5960380811630115, 5.988...
# 4     6.082763  [[6.49007030262754, 6.396616608610273, 6.29854...
# ..         ...                                                ...
# 315   1.732051  [[2.4595259935561944, 2.13687321447145, 1.7994...
# 316   5.567764  [[6.350724019495932, 6.2367929106511255, 6.092...
# 317   4.000000  [[4.174406757166777, 4.365432486282128, 4.4492...
# 318   3.605551  [[3.9255893783938838, 4.055840342082859, 4.171...
# 319   1.732051  [[0.9029442747300814, 0.6685973410045828, 0.48...
#
#      outlier_lims_upper  outlier_remove
# 0              6.877070           False
# 1              3.754119           False
# 2              3.826427           False
# 3              9.091501           False
# 4              8.019766           False
# ..                  ...             ...
# 315            4.964985           False
# 316            6.972928           False
# 317            7.095245           False
# 318            6.628495           False
# 319            4.742684           False
#
# [320 rows x 15 columns]
# ('221020-2-1', 2, '00_go') :     1
# ('221020-2-1', 33, '00_go') :     1
# ('221020-2-1', 66, '00_go') :     1
# ('221020-2-1', 97, '00_go') :     1
# ('221020-2-1', 130, '00_go') :     1
# ('221020-2-1', 161, '00_go') :     1
# ('221020-2-1', 193, '00_go') :     1
# ('221020-2-1', 225, '00_go') :     1
# ('221020-2-1', 257, '00_go') :     1
# ('221020-2-1', 294, '00_go') :     1
# ('221020-2-1', 327, '00_go') :     1
# ('221020-2-1', 367, '00_go') :     1
# ('221020-2-1', 385, '00_go') :     1
# ('221020-2-1', 417, '00_go') :     1
# ('221020-2-1', 449, '00_go') :     1
# ('221020-2-1', 481, '00_go') :     1
# ('221020-2-28', 2, '00_go') :     1
# ('221020-2-28', 33, '00_go') :     1
# ('221020-2-28', 66, '00_go') :     1
# ('221020-2-28', 97, '00_go') :     1
# ('221020-2-28', 130, '00_go') :     1
# ('221020-2-28', 161, '00_go') :     1
# ('221020-2-28', 193, '00_go') :     1
# ('221020-2-28', 225, '00_go') :     1
# ('221020-2-28', 257, '00_go') :     1
# ('221020-2-28', 294, '00_go') :     1
# ('221020-2-28', 327, '00_go') :     1
# ('221020-2-28', 367, '00_go') :     1
# ('221020-2-28', 385, '00_go') :     1
# ('221020-2-28', 417, '00_go') :     1
# ('221020-2-28', 449, '00_go') :     1
# ('221020-2-28', 481, '00_go') :     1
# ('221020-2-61', 2, '00_go') :     1
# ('221020-2-61', 33, '00_go') :     1
# ('221020-2-61', 66, '00_go') :     1
# ('221020-2-61', 97, '00_go') :     1
# ('221020-2-61', 130, '00_go') :     1
# ('221020-2-61', 161, '00_go') :     1
# ('221020-2-61', 193, '00_go') :     1
# ('221020-2-61', 225, '00_go') :     1
# ('221020-2-61', 257, '00_go') :     1
# ('221020-2-61', 294, '00_go') :     1
# ('221020-2-61', 327, '00_go') :     1
# ('221020-2-61', 367, '00_go') :     1
# ('221020-2-61', 385, '00_go') :     1
# ('221020-2-61', 417, '00_go') :     1
# ('221020-2-61', 449, '00_go') :     1
# ('221020-2-61', 481, '00_go') :     1
# ('221020-2-95', 2, '00_go') :     1
# ('221020-2-95', 33, '00_go') :     1
# ('221020-2-95', 66, '00_go') :     1
# ('221020-2-95', 97, '00_go') :     1
# ('221020-2-95', 130, '00_go') :     1
# ('221020-2-95', 161, '00_go') :     1
# ('221020-2-95', 193, '00_go') :     1
# ('221020-2-95', 225, '00_go') :     1
# ('221020-2-95', 257, '00_go') :     1
# ('221020-2-95', 294, '00_go') :     1
# ('221020-2-95', 327, '00_go') :     1
# ('221020-2-95', 367, '00_go') :     1
# ('221020-2-95', 385, '00_go') :     1
# ('221020-2-95', 417, '00_go') :     1
# ('221020-2-95', 449, '00_go') :     1
# ('221020-2-95', 481, '00_go') :     1
# ('221020-2-122', 2, '00_go') :     1
# ('221020-2-534', 33, '00_go') :     1
# ('221020-2-534', 66, '00_go') :     1
# ('221020-2-534', 97, '00_go') :     1
# ('221020-2-534', 130, '00_go') :     1
# ('221020-2-534', 161, '00_go') :     1
# ('221020-2-534', 193, '00_go') :     1
# ('221020-2-534', 225, '00_go') :     1
# ('221020-2-534', 257, '00_go') :     1
# ('221020-2-534', 294, '00_go') :     1
# ('221020-2-534', 327, '00_go') :     1
# ('221020-2-534', 367, '00_go') :     1
# ('221020-2-534', 385, '00_go') :     1
# ('221020-2-534', 417, '00_go') :     1
# ('221020-2-534', 449, '00_go') :     1
# ('221020-2-534', 481, '00_go') :     1
# ('221020-2-561', 2, '00_go') :     1
# ('221020-2-561', 33, '00_go') :     1
# ('221020-2-561', 66, '00_go') :     1
# ('221020-2-561', 97, '00_go') :     1
# ('221020-2-561', 130, '00_go') :     1
# ('221020-2-561', 161, '00_go') :     1
# ('221020-2-561', 193, '00_go') :     1
# ('221020-2-561', 225, '00_go') :     1
# ('221020-2-561', 257, '00_go') :     1
# ('221020-2-561', 294, '00_go') :     1
# ('221020-2-561', 327, '00_go') :     1
# ('221020-2-561', 367, '00_go') :     1
# ('221020-2-561', 385, '00_go') :     1
# ('221020-2-561', 417, '00_go') :     1
# ('221020-2-561', 449, '00_go') :     1
# ('221020-2-561', 481, '00_go') :     1
# ('221020-2-601', 2, '00_go') :     1
# ('221020-2-601', 33, '00_go') :     1
# ('221020-2-601', 66, '00_go') :     1
# ('221020-2-601', 97, '00_go') :     1
# ('221020-2-601', 130, '00_go') :     1
# ('221020-2-601', 161, '00_go') :     1
# ('221020-2-601', 193, '00_go') :     1
# ('221020-2-601', 225, '00_go') :     1
# ('221020-2-601', 257, '00_go') :     1
# ('221020-2-601', 294, '00_go') :     1
# ('221020-2-601', 327, '00_go') :     1
# ('221020-2-601', 367, '00_go') :     1
# ('221020-2-601', 385, '00_go') :     1
# ('221020-2-601', 417, '00_go') :     1
# ('221020-2-601', 449, '00_go') :     1
# ('221020-2-601', 481, '00_go') :     1
# {('221020-2-1', 2, '00_go'): 1,
#  ('221020-2-1', 33, '00_go'): 1,
#  ('221020-2-1', 66, '00_go'): 1,
#  ('221020-2-1', 97, '00_go'): 1,
#  ('221020-2-1', 130, '00_go'): 1,
#  ('221020-2-1', 161, '00_go'): 1,
#  ('221020-2-1', 193, '00_go'): 1,
#  ('221020-2-1', 225, '00_go'): 1,
#  ('221020-2-1', 257, '00_go'): 1,
#  ('221020-2-1', 294, '00_go'): 1,
#  ('221020-2-1', 327, '00_go'): 1,
#  ('221020-2-1', 367, '00_go'): 1,
#  ('221020-2-1', 385, '00_go'): 1,
#  ('221020-2-1', 417, '00_go'): 1,
#  ('221020-2-1', 449, '00_go'): 1,
#  ('221020-2-1', 481, '00_go'): 1,
#  ('221020-2-28', 2, '00_go'): 1,
#  ('221020-2-28', 33, '00_go'): 1,
#  ('221020-2-28', 66, '00_go'): 1,
#  ('221020-2-28', 97, '00_go'): 1,
#  ('221020-2-28', 130, '00_go'): 1,
#  ('221020-2-28', 161, '00_go'): 1,
#  ('221020-2-28', 193, '00_go'): 1,
#  ('221020-2-28', 225, '00_go'): 1,
#  ('221020-2-28', 257, '00_go'): 1,
#  ('221020-2-28', 294, '00_go'): 1,
#  ('221020-2-28', 327, '00_go'): 1,
#  ('221020-2-28', 367, '00_go'): 1,
#  ('221020-2-28', 385, '00_go'): 1,
#  ('221020-2-28', 417, '00_go'): 1,
#  ('221020-2-28', 449, '00_go'): 1,
#  ('221020-2-28', 481, '00_go'): 1,
#  ('221020-2-61', 2, '00_go'): 1,
#  ('221020-2-61', 33, '00_go'): 1,
#  ('221020-2-61', 66, '00_go'): 1,
#  ('221020-2-61', 97, '00_go'): 1,
#  ('221020-2-61', 130, '00_go'): 1,
#  ('221020-2-61', 161, '00_go'): 1,
#  ('221020-2-61', 193, '00_go'): 1,
#  ('221020-2-61', 225, '00_go'): 1,
#  ('221020-2-61', 257, '00_go'): 1,
#  ('221020-2-61', 294, '00_go'): 1,
#  ('221020-2-61', 327, '00_go'): 1,
#  ('221020-2-61', 367, '00_go'): 1,
#  ('221020-2-61', 385, '00_go'): 1,
#  ('221020-2-61', 417, '00_go'): 1,
#  ('221020-2-61', 449, '00_go'): 1,
#  ('221020-2-61', 481, '00_go'): 1,
#  ('221020-2-95', 2, '00_go'): 1,
#  ('221020-2-95', 33, '00_go'): 1,
#  ('221020-2-95', 66, '00_go'): 1,
#  ('221020-2-95', 97, '00_go'): 1,
#  ('221020-2-95', 130, '00_go'): 1,
#  ('221020-2-95', 161, '00_go'): 1,
#  ('221020-2-95', 193, '00_go'): 1,
#  ('221020-2-95', 225, '00_go'): 1,
#  ('221020-2-95', 257, '00_go'): 1,
#  ('221020-2-95', 294, '00_go'): 1,
#  ('221020-2-95', 327, '00_go'): 1,
#  ('221020-2-95', 367, '00_go'): 1,
#  ('221020-2-95', 385, '00_go'): 1,
#  ('221020-2-95', 417, '00_go'): 1,
#  ('221020-2-95', 449, '00_go'): 1,
#  ('221020-2-95', 481, '00_go'): 1,
#  ('221020-2-122', 2, '00_go'): 1,
#  ('221020-2-122', 33, '00_go'): 1,
#  ('221020-2-122', 66, '00_go'): 1,
#  ('221020-2-122', 97, '00_go'): 1,
#  ('221020-2-122', 130, '00_go'): 1,
#  ('221020-2-122', 161, '00_go'): 1,
#  ('221020-2-122', 193, '00_go'): 1,
#  ('221020-2-122', 225, '00_go'): 1,
#  ('221020-2-122', 257, '00_go'): 1,
#  ('221020-2-122', 294, '00_go'): 1,
#  ('221020-2-122', 327, '00_go'): 1,
#  ('221020-2-122', 367, '00_go'): 1,
#  ('221020-2-122', 385, '00_go'): 1,
#  ('221020-2-122', 417, '00_go'): 1,
#  ('221020-2-122', 449, '00_go'): 1,
#  ('221020-2-122', 481, '00_go'): 1,
#  ('221020-2-160', 2, '00_go'): 1,
#  ('221020-2-160', 33, '00_go'): 1,
#  ('221020-2-160', 66, '00_go'): 1,
#  ('221020-2-160', 97, '00_go'): 1,
#  ('221020-2-160', 130, '00_go'): 1,
#  ('221020-2-160', 161, '00_go'): 1,
#  ('221020-2-160', 193, '00_go'): 1,
#  ('221020-2-160', 225, '00_go'): 1,
#  ('221020-2-160', 257, '00_go'): 1,
#  ('221020-2-160', 294, '00_go'): 1,
#  ('221020-2-160', 327, '00_go'): 1,
#  ('221020-2-160', 367, '00_go'): 1,
#  ('221020-2-160', 385, '00_go'): 1,
#  ('221020-2-160', 417, '00_go'): 1,
#  ('221020-2-160', 449, '00_go'): 1,
#  ('221020-2-160', 481, '00_go'): 1,
#  ('221020-2-190', 2, '00_go'): 1,
#  ('221020-2-190', 33, '00_go'): 1,
#  ('221020-2-190', 66, '00_go'): 1,
#  ('221020-2-190', 97, '00_go'): 1,
#  ('221020-2-190', 130, '00_go'): 1,
#  ('221020-2-190', 161, '00_go'): 1,
#  ('221020-2-190', 193, '00_go'): 1,
#  ('221020-2-190', 225, '00_go'): 1,
#  ('221020-2-190', 257, '00_go'): 1,
#  ('221020-2-190', 294, '00_go'): 1,
#  ('221020-2-190', 327, '00_go'): 1,
#  ('221020-2-190', 367, '00_go'): 1,
#  ('221020-2-190', 385, '00_go'): 1,
#  ('221020-2-190', 417, '00_go'): 1,
#  ('221020-2-190', 449, '00_go'): 1,
#  ('221020-2-190', 481, '00_go'): 1,
#  ('221020-2-221', 2, '00_go'): 1,
#  ('221020-2-221', 33, '00_go'): 1,
#  ('221020-2-221', 66, '00_go'): 1,
#  ('221020-2-221', 97, '00_go'): 1,
#  ('221020-2-221', 130, '00_go'): 1,
#  ('221020-2-221', 161, '00_go'): 1,
#  ('221020-2-221', 193, '00_go'): 1,
#  ('221020-2-221', 225, '00_go'): 1,
#  ('221020-2-221', 257, '00_go'): 1,
#  ('221020-2-221', 294, '00_go'): 1,
#  ('221020-2-221', 327, '00_go'): 1,
#  ('221020-2-221', 367, '00_go'): 1,
#  ('221020-2-221', 385, '00_go'): 1,
#  ('221020-2-221', 417, '00_go'): 1,
#  ('221020-2-221', 449, '00_go'): 1,
#  ('221020-2-221', 481, '00_go'): 1,
#  ('221020-2-252', 2, '00_go'): 1,
#  ('221020-2-252', 33, '00_go'): 1,
#  ('221020-2-252', 66, '00_go'): 1,
#  ('221020-2-252', 97, '00_go'): 1,
#  ('221020-2-252', 130, '00_go'): 1,
#  ('221020-2-252', 161, '00_go'): 1,
#  ('221020-2-252', 193, '00_go'): 1,
#  ('221020-2-252', 225, '00_go'): 1,
#  ('221020-2-252', 257, '00_go'): 1,
#  ('221020-2-252', 294, '00_go'): 1,
#  ('221020-2-252', 327, '00_go'): 1,
#  ('221020-2-252', 367, '00_go'): 1,
#  ('221020-2-252', 385, '00_go'): 1,
#  ('221020-2-252', 417, '00_go'): 1,
#  ('221020-2-252', 449, '00_go'): 1,
#  ('221020-2-252', 481, '00_go'): 1,
#  ('221020-2-280', 2, '00_go'): 1,
#  ('221020-2-280', 33, '00_go'): 1,
#  ('221020-2-280', 66, '00_go'): 1,
#  ('221020-2-280', 97, '00_go'): 1,
#  ('221020-2-280', 130, '00_go'): 1,
#  ('221020-2-280', 161, '00_go'): 1,
#  ('221020-2-280', 193, '00_go'): 1,
#  ('221020-2-280', 225, '00_go'): 1,
#  ('221020-2-280', 257, '00_go'): 1,
#  ('221020-2-280', 294, '00_go'): 1,
#  ('221020-2-280', 327, '00_go'): 1,
#  ('221020-2-280', 367, '00_go'): 1,
#  ('221020-2-280', 385, '00_go'): 1,
#  ('221020-2-280', 417, '00_go'): 1,
#  ('221020-2-280', 449, '00_go'): 1,
#  ('221020-2-280', 481, '00_go'): 1,
#  ('221020-2-315', 2, '00_go'): 1,
#  ('221020-2-315', 33, '00_go'): 1,
#  ('221020-2-315', 66, '00_go'): 1,
#  ('221020-2-315', 97, '00_go'): 1,
#  ('221020-2-315', 130, '00_go'): 1,
#  ('221020-2-315', 161, '00_go'): 1,
#  ('221020-2-315', 193, '00_go'): 1,
#  ('221020-2-315', 225, '00_go'): 1,
#  ('221020-2-315', 257, '00_go'): 1,
#  ('221020-2-315', 294, '00_go'): 1,
#  ('221020-2-315', 327, '00_go'): 1,
#  ('221020-2-315', 367, '00_go'): 1,
#  ('221020-2-315', 385, '00_go'): 1,
#  ('221020-2-315', 417, '00_go'): 1,
#  ('221020-2-315', 449, '00_go'): 1,
#  ('221020-2-315', 481, '00_go'): 1,
#  ('221020-2-343', 2, '00_go'): 1,
#  ('221020-2-343', 33, '00_go'): 1,
#  ('221020-2-343', 66, '00_go'): 1,
#  ('221020-2-343', 97, '00_go'): 1,
#  ('221020-2-343', 130, '00_go'): 1,
#  ('221020-2-343', 161, '00_go'): 1,
#  ('221020-2-343', 193, '00_go'): 1,
#  ('221020-2-343', 225, '00_go'): 1,
#  ('221020-2-343', 257, '00_go'): 1,
#  ('221020-2-343', 294, '00_go'): 1,
#  ('221020-2-343', 327, '00_go'): 1,
#  ('221020-2-343', 367, '00_go'): 1,
#  ('221020-2-343', 385, '00_go'): 1,
#  ('221020-2-343', 417, '00_go'): 1,
#  ('221020-2-343', 449, '00_go'): 1,
#  ('221020-2-343', 481, '00_go'): 1,
#  ('221020-2-375', 2, '00_go'): 1,
#  ('221020-2-375', 33, '00_go'): 1,
#  ('221020-2-375', 66, '00_go'): 1,
#  ('221020-2-375', 97, '00_go'): 1,
#  ('221020-2-375', 130, '00_go'): 1,
#  ('221020-2-375', 161, '00_go'): 1,
#  ('221020-2-375', 193, '00_go'): 1,
#  ('221020-2-375', 225, '00_go'): 1,
#  ('221020-2-375', 257, '00_go'): 1,
#  ('221020-2-375', 294, '00_go'): 1,
#  ('221020-2-375', 327, '00_go'): 1,
#  ('221020-2-375', 367, '00_go'): 1,
#  ('221020-2-375', 385, '00_go'): 1,
#  ('221020-2-375', 417, '00_go'): 1,
#  ('221020-2-375', 449, '00_go'): 1,
#  ('221020-2-375', 481, '00_go'): 1,
#  ('221020-2-411', 2, '00_go'): 1,
#  ('221020-2-411', 33, '00_go'): 1,
#  ('221020-2-411', 66, '00_go'): 1,
#  ('221020-2-411', 97, '00_go'): 1,
#  ('221020-2-411', 130, '00_go'): 1,
#  ('221020-2-411', 161, '00_go'): 1,
#  ('221020-2-411', 193, '00_go'): 1,
#  ('221020-2-411', 225, '00_go'): 1,
#  ('221020-2-411', 257, '00_go'): 1,
#  ('221020-2-411', 294, '00_go'): 1,
#  ('221020-2-411', 327, '00_go'): 1,
#  ('221020-2-411', 367, '00_go'): 1,
#  ('221020-2-411', 385, '00_go'): 1,
#  ('221020-2-411', 417, '00_go'): 1,
#  ('221020-2-411', 449, '00_go'): 1,
#  ('221020-2-411', 481, '00_go'): 1,
#  ('221020-2-444', 2, '00_go'): 1,
#  ('221020-2-444', 33, '00_go'): 1,
#  ('221020-2-444', 66, '00_go'): 1,
#  ('221020-2-444', 97, '00_go'): 1,
#  ('221020-2-444', 130, '00_go'): 1,
#  ('221020-2-444', 161, '00_go'): 1,
#  ('221020-2-444', 193, '00_go'): 1,
#  ('221020-2-444', 225, '00_go'): 1,
#  ('221020-2-444', 257, '00_go'): 1,
#  ('221020-2-444', 294, '00_go'): 1,
#  ('221020-2-444', 327, '00_go'): 1,
#  ('221020-2-444', 367, '00_go'): 1,
#  ('221020-2-444', 385, '00_go'): 1,
#  ('221020-2-444', 417, '00_go'): 1,
#  ('221020-2-444', 449, '00_go'): 1,
#  ('221020-2-444', 481, '00_go'): 1,
#  ('221020-2-472', 2, '00_go'): 1,
#  ('221020-2-472', 33, '00_go'): 1,
#  ('221020-2-472', 66, '00_go'): 1,
#  ('221020-2-472', 97, '00_go'): 1,
#  ('221020-2-472', 130, '00_go'): 1,
#  ('221020-2-472', 161, '00_go'): 1,
#  ('221020-2-472', 193, '00_go'): 1,
#  ('221020-2-472', 225, '00_go'): 1,
#  ('221020-2-472', 257, '00_go'): 1,
#  ('221020-2-472', 294, '00_go'): 1,
#  ('221020-2-472', 327, '00_go'): 1,
#  ('221020-2-472', 367, '00_go'): 1,
#  ('221020-2-472', 385, '00_go'): 1,
#  ('221020-2-472', 417, '00_go'): 1,
#  ('221020-2-472', 449, '00_go'): 1,
#  ('221020-2-472', 481, '00_go'): 1,
#  ('221020-2-506', 2, '00_go'): 1,
#  ('221020-2-506', 33, '00_go'): 1,
#  ('221020-2-506', 66, '00_go'): 1,
#  ('221020-2-506', 97, '00_go'): 1,
#  ('221020-2-506', 130, '00_go'): 1,
#  ('221020-2-506', 161, '00_go'): 1,
#  ('221020-2-506', 193, '00_go'): 1,
#  ('221020-2-506', 225, '00_go'): 1,
#  ('221020-2-506', 257, '00_go'): 1,
#  ('221020-2-506', 294, '00_go'): 1,
#  ('221020-2-506', 327, '00_go'): 1,
#  ('221020-2-506', 367, '00_go'): 1,
#  ('221020-2-506', 385, '00_go'): 1,
#  ('221020-2-506', 417, '00_go'): 1,
#  ('221020-2-506', 449, '00_go'): 1,
#  ('221020-2-506', 481, '00_go'): 1,
#  ('221020-2-534', 2, '00_go'): 1,
#  ('221020-2-534', 33, '00_go'): 1,
#  ('221020-2-534', 66, '00_go'): 1,
#  ('221020-2-534', 97, '00_go'): 1,
#  ('221020-2-534', 130, '00_go'): 1,
#  ('221020-2-534', 161, '00_go'): 1,
#  ('221020-2-534', 193, '00_go'): 1,
#  ('221020-2-534', 225, '00_go'): 1,
#  ('221020-2-534', 257, '00_go'): 1,
#  ('221020-2-534', 294, '00_go'): 1,
#  ('221020-2-534', 327, '00_go'): 1,
#  ('221020-2-534', 367, '00_go'): 1,
#  ('221020-2-534', 385, '00_go'): 1,
#  ('221020-2-534', 417, '00_go'): 1,
#  ('221020-2-534', 449, '00_go'): 1,
#  ('221020-2-534', 481, '00_go'): 1,
#  ('221020-2-561', 2, '00_go'): 1,
#  ('221020-2-561', 33, '00_go'): 1,
#  ('221020-2-561', 66, '00_go'): 1,
#  ('221020-2-561', 97, '00_go'): 1,
#  ('221020-2-561', 130, '00_go'): 1,
#  ('221020-2-561', 161, '00_go'): 1,
#  ('221020-2-561', 193, '00_go'): 1,
#  ('221020-2-561', 225, '00_go'): 1,
#  ('221020-2-561', 257, '00_go'): 1,
#  ('221020-2-561', 294, '00_go'): 1,
#  ('221020-2-561', 327, '00_go'): 1,
#  ('221020-2-561', 367, '00_go'): 1,
#  ('221020-2-561', 385, '00_go'): 1,
#  ('221020-2-561', 417, '00_go'): 1,
#  ('221020-2-561', 449, '00_go'): 1,
#  ('221020-2-561', 481, '00_go'): 1,
#  ('221020-2-601', 2, '00_go'): 1,
#  ('221020-2-601', 33, '00_go'): 1,
#  ('221020-2-601', 66, '00_go'): 1,
#  ('221020-2-601', 97, '00_go'): 1,
#  ('221020-2-601', 130, '00_go'): 1,
#  ('221020-2-601', 161, '00_go'): 1,
#  ('221020-2-601', 193, '00_go'): 1,
#  ('221020-2-601', 225, '00_go'): 1,
#  ('221020-2-601', 257, '00_go'): 1,
#  ('221020-2-601', 294, '00_go'): 1,
#  ('221020-2-601', 327, '00_go'): 1,
#  ('221020-2-601', 367, '00_go'): 1,
#  ('221020-2-601', 385, '00_go'): 1,
#  ('221020-2-601', 417, '00_go'): 1,
#  ('221020-2-601', 449, '00_go'): 1,
#  ('221020-2-601', 481, '00_go'): 1}

# %% [markdown]
# ##### Plotting functions for Snippets

# %%
chan =2
SP.plotgood_rasters(chan)
# Out:
# (<Figure size 210x350 with 1 Axes>,
#  array([[<Axes: ylabel='trial'>]], dtype=object))

# %%
# Rasters and smoothed FR, split by event
chan = 2
SP.plotgood_rasters_smfr_each_level_combined(chan, var="event")

# %%
# you can further split data based on conjucntions of another set of variables.

# For example, let's make that same plot, but split subplots by epoch.
SP.datasetbeh_append_column("epoch", sn.Datasetbeh) # assign epoch to SP
SP.plotgood_rasters_smfr_each_level_combined(chan, var="event", vars_others=["epoch"]) # plot

# %%
# We can plot the same data, but flipping which variable
SP.plotgood_rasters_smfr_each_level_combined(chan, var="epoch", vars_others=["event"]) # plot

# %%
# You can even use conjucjtions of mltiple variables for splitting suybplots
SP.datasetbeh_append_column("epoch", sn.Datasetbeh) # assign epoch to SP
SP.datasetbeh_append_column("block", sn.Datasetbeh) # assign epoch to SP

SP.plotgood_rasters_smfr_each_level_combined(chan, var="event", vars_others=["epoch", "block"]) # plot

# Now each subplot is a specific conjucntion of the variables epoch and block.

# %% [markdown]
# ### Computing modulation of activity by certain variables

# %% [markdown]
# For each site, compute how strongly it is modulated by a specific variable, computed
# separatedly for each event.

# %%
# First, append the variables that you wish to analyze
SP.datasetbeh_append_column("epoch", sn.Datasetbeh) # assign epoch to SP
# Out:
# Updating this column of self.DfScalar with Dataset beh:
# epoch

# %%
if DEBUG:
    # if you debug, then you have small n trials, so lower the threshold for keeping data.
    print(SP.ParamsGlobals)
    SP.globals_update(globals_nmin=2)
# Out:
# {'n_min_trials_per_level': 5, 'lenient_allow_data_if_has_n_levels': 2, 'PRE_DUR_CALC': -0.5, 'POST_DUR_CALC': 0.5, 'list_events': ['00_go'], 'list_pre_dur': [-0.5], 'list_post_dur': [0.5]}
# Updated self.ParamsGlobals:
# n_min_trials_per_level  =  2
# lenient_allow_data_if_has_n_levels  =  2
# PRE_DUR_CALC  =  -0.5
# POST_DUR_CALC  =  0.5
# list_events  =  ['00_go']
# list_pre_dur  =  [-0.5]
# list_post_dur  =  [0.5]

# %%
# Run this to compute modulation
DF_VAR, DF_FR, DF_FR_LEVELS, list_eventwindow_event = SP.modulationgood_compute_wrapper("epoch", 
                                                                                        DEBUG_CONJUNCTIONS=False, 
                                                                                        THINGS_TO_EXTRACT=["anova"])
# Out:
# Running grouping_print_n_samples...
# DOing these! ...
# list_events ['00_go']
# list_pre_dur [-0.5]
# list_post_dur [0.5]
# GOOD!, enough data, max n per grouping conjunction (nmin, nmax)  9 11
#
# Updated ParamsGlobals for event 00_go to:
# Updated self.ParamsGlobals:
# n_min_trials_per_level  =  2
# lenient_allow_data_if_has_n_levels  =  2
# PRE_DUR_CALC  =  -0.5
# POST_DUR_CALC  =  0.5
# list_events  =  ['00_go']
# list_pre_dur  =  [-0.5]
# list_post_dur  =  [0.5]
# DOING THIS EVENT:  00_go_-500_to_500
# 00_go
#         trialcode  chan event_unique_name event_aligned  \
# 0      221020-2-1     2             00_go         00_go
# 1      221020-2-1    33             00_go         00_go
# 2      221020-2-1    66             00_go         00_go
# 3      221020-2-1    97             00_go         00_go
# 4      221020-2-1   130             00_go         00_go
# ..            ...   ...               ...           ...
# 315  221020-2-601   367             00_go         00_go
# 316  221020-2-601   385             00_go         00_go
# 317  221020-2-601   417             00_go         00_go
# 318  221020-2-601   449             00_go         00_go
# 319  221020-2-601   481             00_go         00_go
#
#                                            spike_times  trial_neural  \
# 0    [-0.48693204521124756, -0.41336788521124745, -...             0
# 1    [-0.35831764521124754, -0.30871508521124724, -...             0
# 2            [-0.308756045211247, 0.12967979478875336]             0
# 3    [-0.4809109252112478, -0.45699028521124774, -0...             0
# 4    [-0.47144916521124713, -0.46317524521124653, -...             0
# ..                                                 ...           ...
# 315  [-0.19179940720823652, -0.03934628720890032, 0...           600
# 316  [-0.48765348720917245, -0.44571044720942155, -...           600
# 317  [-0.48507300720848434, -0.46451108720793854, -...           600
# 318  [-0.47430052720847016, -0.43530660720898595, -...           600
# 319  [0.08746587279165396, 0.21063259279071644, 0.2...           600
#
#      event_time                                              fr_sm  \
# 0      5.199432  [[11.346740799682868, 11.836989504350855, 12.0...
# 1      5.199432  [[9.646250259959345, 8.078632492421304, 6.5072...
# 2      5.199432  [[0.0003995935276705609, 0.001192965913530486,...
# 3      5.199432  [[27.262442194225635, 31.315642205826595, 35.8...
# 4      5.199432  [[42.12101253304793, 40.91670403754879, 39.671...
# ..          ...                                                ...
# 315    3.757983  [[6.049268112978585, 4.566227134725548, 3.2379...
# 316    3.757983  [[40.33169557180256, 38.89758581034813, 37.120...
# 317    3.757983  [[17.425671774279643, 19.05700079228736, 19.79...
# 318    3.757983  [[15.41025196775888, 16.449840880466798, 17.39...
# 319    3.757983  [[0.8153083632678328, 0.4470224043983984, 0.23...
#
#                                            fr_sm_times event  fr_scalar_raw  \
# 0    [[-0.495, -0.4850000000000002, -0.474999999999...    go           39.0
# 1    [[-0.495, -0.4850000000000002, -0.474999999999...    go            6.0
# 2    [[-0.495, -0.4850000000000002, -0.474999999999...    go            2.0
# 3    [[-0.495, -0.4850000000000002, -0.474999999999...    go           65.0
# 4    [[-0.495, -0.4850000000000002, -0.474999999999...    go           37.0
# ..                                                 ...   ...            ...
# 315  [[-0.495, -0.4850000000000002, -0.474999999999...    go            3.0
# 316  [[-0.495, -0.4850000000000002, -0.474999999999...    go           31.0
# 317  [[-0.495, -0.4850000000000002, -0.474999999999...    go           16.0
# 318  [[-0.495, -0.4850000000000002, -0.474999999999...    go           13.0
# 319  [[-0.495, -0.4850000000000002, -0.474999999999...    go            3.0
#
#      fr_scalar                                         fr_sm_sqrt  \
# 0     6.244998  [[3.368492363013885, 3.4404926252429107, 3.472...
# 1     2.449490  [[3.1058413127459272, 2.842293526788059, 2.550...
# 2     1.414214  [[0.019989835608892857, 0.034539338637711144, ...
# 3     8.062258  [[5.221344864517726, 5.5960380811630115, 5.988...
# 4     6.082763  [[6.49007030262754, 6.396616608610273, 6.29854...
# ..         ...                                                ...
# 315   1.732051  [[2.4595259935561944, 2.13687321447145, 1.7994...
# 316   5.567764  [[6.350724019495932, 6.2367929106511255, 6.092...
# 317   4.000000  [[4.174406757166777, 4.365432486282128, 4.4492...
# 318   3.605551  [[3.9255893783938838, 4.055840342082859, 4.171...
# 319   1.732051  [[0.9029442747300814, 0.6685973410045828, 0.48...
#
#      outlier_lims_upper  outlier_remove epoch dummy_var
# 0              6.877070           False     L     dummy
# 1              3.754119           False     L     dummy
# 2              3.826427           False     L     dummy
# 3              9.091501           False     L     dummy
# 4              8.019766           False     L     dummy
# ..                  ...             ...   ...       ...
# 315            4.964985           False  llV1     dummy
# 316            6.972928           False  llV1     dummy
# 317            7.095245           False  llV1     dummy
# 318            6.628495           False  llV1     dummy
# 319            4.742684           False  llV1     dummy
#
# [320 rows x 17 columns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Run this to compute modulation
# ----> 2 DF_VAR, DF_FR, DF_FR_LEVELS, list_eventwindow_event = SP.modulationgood_compute_wrapper("epoch",
#       3                                                                                         DEBUG_CONJUNCTIONS=False,
#       4                                                                                         THINGS_TO_EXTRACT=["anova"])
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/snippets.py:2443, in Snippets.modulationgood_compute_wrapper(self, var, vars_conjuction, list_site, score_ver, get_z_score, DEBUG_CONJUNCTIONS, events_windowed_skip, SAVEDIR, THINGS_TO_EXTRACT)
#    2436 region = sn.sitegetter_map_site_to_region(site)
#    2438 # Clean up dataset
#    2439 # print(var)
#    2440 # print(vars_conjuction)
#    2441 # print(site)
#    2442 # print(event)
# -> 2443 dfthis, levs_df, levels_var = self.dataextract_as_df_conjunction_vars(var,
#    2444     vars_conjuction, site, event=event, DEBUG_CONJUNCTIONS=DEBUG_CONJUNCTIONS)
#    2445 # print(len(dfthis))
#    2446 # assert False
#    2447 if len(dfthis)==0:
#
# File ~/Desktop/neuralmonkey/neuralmonkey/classes/snippets.py:1374, in Snippets.dataextract_as_df_conjunction_vars(self, var, vars_others, site, event, DEBUG_CONJUNCTIONS, OVERWRITE_n_min, OVERWRITE_lenient_n, DFTHIS, balance_no_missed_conjunctions, exclude_othervar_levels_missing_any_var_level, PRINT_AND_SAVE_TO, ignore_values_called_ignore)
#    1372         print(event)
#    1373         print(DFTHIS)
# -> 1374         assert False, "This event doesnt exist!!"
#    1376 # 1) extract for this site.
#    1377 if site is None and event is None:
#
# AssertionError: This event doesnt exist!!

# %%
# Plot results and save
sdir_base = "/tmp"
SP.modulationgood_plot_WRAPPER(DF_VAR, DF_FR, DF_FR_LEVELS, list_eventwindow_event, 
                               var="epoch", vars_conjuction=["dummy_var"],
                               sdir_base=sdir_base, N_WAYS=1)
# Out:
# /tmp/modulation
# ** Plotting summarystats
# Saving at: /tmp/modulation
# Found this var:  epoch
# Found this var_others:  ('dummy_var',)
# Aggregating dataframe over all othervars ...
# Plotting ...
# /gorilla1/code/pythonlib/pythonlib/tools/snstools.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list_text,rotation=rotation, horizontalalignment="right")
# ** Plotting heatmaps
# /tmp/modulation_heatmap
# Saving to:  /tmp/modulation_heatmap/brainschem-event-val-modulation_subgroups.pdf
# Saving to:  /tmp/modulation_heatmap/brainschem-event-val-modulation_subgroups-NOMOTOR.pdf
# ** Making plots for this event_window:
# 00_go_-500_to_500
# Saving this event, 00_go_-500_to_500, to /tmp/EACH_EVENT/00_go_-500_to_500

# %%
### Modulation by time (relative to aligned events)

For each site x event, compute a scalar value indiicating how much its actiivyt is modulated
with respect to this event. This moudlation can be increase in fr, decrease, or any
activity pattern that is consistent across trials.

# Extract modulation, for each site x event

from neuralmonkey.analyses.event_temporal_modulation_v2 import preprocess_and_extract
from neuralmonkey.analyses.event_temporal_modulation import plot_overview

df_modtime = preprocess_and_extract(SP)


# Plot overview of modulation

from neuralmonkey.analyses.event_temporal_modulation_v2 import plot_overview
SAVEDIR = "/tmp"
##################### PLOTS
plot_overview(df_modtime, SP, SAVEDIR)
