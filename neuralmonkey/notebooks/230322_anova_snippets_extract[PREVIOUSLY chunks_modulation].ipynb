# %%
"""
6/25/23 - Renamed this was previously
230322_chunks_modulation

To better reflect what it does.
"""
# Out:
# '\n6/25/23 - Renamed this was previously\n230322_chunks_modulation\n\nTo better reflect what it does.\n'

# %%
""" 
Moudlaiton relative to strokes, but now caring a lto about the variables for each stroke.
This is like 230322_event_temporal_modulation, but there just cared about stroke onset/offset.

This is like anova analysis, but there was using activity at trial onset, not aligned to each stroke (or whatever).

"""

# from IPython.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# ' \nMoudlaiton relative to strokes, but now caring a lto about the variables for each stroke.\nThis is like 230322_event_temporal_modulation, but there just cared about stroke onset/offset.\n\nThis is like anova analysis, but there was using activity at trial onset, not aligned to each stroke (or whatever).\n\n'

# %% [markdown]
# ##### Load neural and beh data (pending: cam)

# %%
from neuralmonkey.classes.session import Session
import matplotlib.pyplot as plt
from neuralmonkey.scripts.load_and_save_locally import load_and_preprocess_single_session
import neuralmonkey.utils.monkeylogic as mkl
from neuralmonkey.classes.session import load_session_helper, load_mult_session_helper
import os

# %% [markdown]
# ##### LOAD DATA

# %%
# DATE = 221119
# DATE = 221024
DATE = 230614
# DATE = 220715
# DATE = 220901
animal = "Pancho"

# %%
# %matplotlib inline
# to help debug if times are misaligned.
MINIMAL_LOADING = True
MS = load_mult_session_helper(DATE, animal, MINIMAL_LOADING=MINIMAL_LOADING)
# Out:
# Searching using this string:
# /mnt/hopfield_data01/ltian/recordings/*Pancho*/*230614*/**
# Found this many paths:
# 1
# ---
# /mnt/hopfield_data01/ltian/recordings/Pancho/230614/Pancho-230614-152109
# session:  0
# Beh Sessions that exist on this date:  {230614: [(1, 'primsingridvar3')]}
# ------------------------------
# Loading this neural session: 0
# Loading these beh expts: ['primsingridvar3']
# Loading these beh sessions: [1]
# Using this beh_trial_map_list: [(1, 0)]
# Searching using this string:
# /mnt/hopfield_data01/ltian/recordings/*Pancho*/*230614*/**
# Found this many paths:
# 1
# ---
# /mnt/hopfield_data01/ltian/recordings/Pancho/230614/Pancho-230614-152109
# ...

# %%
ANALY_VER = "trial_seqcontext"
# ANALY_VER = "trial_rulesw"
# ANALY_VER = "singleprim"

# %% [markdown]
# ### TRY APPLYING PARAMS to D

# %%
from neuralmonkey.metadat.analy.anova_params import dataset_apply_params, conjunctions_print_plot_all

# %%
### Prep dataset, and extract params
ListD = [sn.Datasetbeh for sn in MS.SessionsList]
which_level = "trial"
ANALY_VER = "seqcontextvar"
Dall, Dpruned, TRIALCODES_KEEP, params, params_extraction = dataset_apply_params(ListD, 
    animal, DATE, which_level, ANALY_VER)
# Out:
# Got these LIST_VAR and LIST_VARS_CONJUNCTION:
# ['seqc_0_shape', 'seqc_0_loc', 'seqc_0_shape', 'seqc_0_loc']
# [['epochset', 'epoch', 'seqc_0_loc'], ['epochset', 'epoch', 'seqc_0_shape'], ['epoch', 'seqc_0_loc'], ['epoch', 'seqc_0_shape']]
# stored in self.Dat[BehClass]
# 0
# 200
# 400
# Running D.behclass_tokens_extract_datsegs
# 0
# 200
# 400
# Done!, new len of dataset 487
# stored in self.Dat[BehClass]
# 0
# 200
# 400
# Running D.behclass_tokens_extract_datsegs
# 0
# 200
# 400
# Appended columns gridsize!
# Defined new column: epochset
# ... merge_sets_with_only_single_epoch...
# ('singleprim',) only has one epoch!:  ['singleprim']
# Mergin these epochset's ..
# [('singleprim',)]
# Into this new epochset: ('LEFTOVER',)
# -- Final epochsets:
# (oneloc_varyshp, oneshp_varyloc, varyloc_varyshp)    293
# (oneloc_varyshp, varyloc_varyshp)                    115
# (LEFTOVER,)                                           79
# Name: epochset, dtype: int64
# ...

# %%
conjunctions_print_plot_all([Dall], "/tmp", ANALY_VER, which_level)
# Out:
# Got these LIST_VAR and LIST_VARS_CONJUNCTION:
# ['seqc_0_shape', 'seqc_0_loc', 'seqc_0_shape', 'seqc_0_loc']
# [['epochset', 'epoch', 'seqc_0_loc'], ['epochset', 'epoch', 'seqc_0_shape'], ['epoch', 'seqc_0_loc'], ['epoch', 'seqc_0_shape']]
# stored in self.Dat[BehClass]
# 0
# 200
# 400
# Running D.behclass_tokens_extract_datsegs
# 0
# 200
# 400
# Done!, new len of dataset 487
# stored in self.Dat[BehClass]
# 0
# 200
# 400
# Running D.behclass_tokens_extract_datsegs
# 0
# 200
# 400
# Appended columns gridsize!
# Defined new column: epochset
# ... merge_sets_with_only_single_epoch...
# ('singleprim',) only has one epoch!:  ['singleprim']
# Mergin these epochset's ..
# [('singleprim',)]
# Into this new epochset: ('LEFTOVER',)
# -- Final epochsets:
# (oneloc_varyshp, oneshp_varyloc, varyloc_varyshp)    293
# (oneloc_varyshp, varyloc_varyshp)                    115
# (LEFTOVER,)                                           79
# Name: epochset, dtype: int64
# ...

# %% [markdown]
# ### DEVO Code for params

# %% [markdown]
# #### Print summaries of datasets

# %%
# print summary:|
MS.print_summary_sessions()

# %%
session = 0

sn = MS.SessionsList[session]
D = sn.Datasetbeh
    
if False:
    SAVEDIR = f"/gorilla1/analyses/recordings/main/chunks_modulation/{animal}-{DATE}-sess_{session}"
    os.makedirs(SAVEDIR, exist_ok=True)

# %%
del MS.SessionsList[3]
del MS.SessionsList[2]
del MS.SessionsList[1]
# del MS.SessionsList[0]

# %%
Dcopy = D.copy()
Dcopy.preprocessGood(params=['sanity_gridloc_identical'])

# %%
221024

# %%
D.sequence_extract_beh_and_task(103, True)

# %% [markdown]
# ##### epoch kind

# %%
D.supervision_epochs_extract_epochkind()

# %%
D.Dat["epochkind"].value_counts()

# %% [markdown]
# ##### First, how to compute score fore ach beh

# %%
D.grammar_successbinary_score_matlab(True)

# %%
D.GrammarDict = {}
D.grammar_successbinary_score_parses(True)

# %% [markdown]
# Plot example successes and faillures

# %%
D.Dat["success_binary_quick"].value_counts()

# %%
D.Dat[D.Dat["success_binary_quick"]==True].index.tolist()
D.Dat[D.Dat["success_binary_quick"]==False].index.tolist()

# %%
D.sequence_extract_beh_and_task(263, True)

# %% [markdown]
# #### Loc shape configs

# %%
D.taskclass_shapes_loc_configuration_assign_column()

# %%
# conjunction of config and epoch (e.g, for singleprimvar)

D.grouping_print_n_samples(["epoch", "taskconfig_shploc"])
# Out:
# ('oneloc_varyshp', (('Lcentered-4-3-0', (-1, -1)), ('V-2-2-0', (1, 1)))) :     10
# ('oneloc_varyshp', (('Lcentered-4-3-0', (-1, 1)), ('Lcentered-4-3-0', (-1, -1)))) :     10
# ('oneloc_varyshp', (('Lcentered-4-3-0', (-1, 1)), ('Lcentered-4-3-0', (1, 1)))) :     9
# ('oneloc_varyshp', (('Lcentered-4-3-0', (-1, 1)), ('V-2-2-0', (-1, -1)))) :     9
# ('oneloc_varyshp', (('Lcentered-4-3-0', (-1, 1)), ('V-2-2-0', (1, 1)))) :     9
# ('oneloc_varyshp', (('Lcentered-4-3-0', (1, 1)), ('Lcentered-4-3-0', (-1, -1)))) :     10
# ('oneloc_varyshp', (('Lcentered-4-3-0', (1, 1)), ('V-2-4-0', (-1, -1)))) :     11
# ('oneloc_varyshp', (('V-2-2-0', (-1, -1)), ('V-2-2-0', (1, 1)))) :     10
# ('oneloc_varyshp', (('V-2-2-0', (-1, -1)), ('V-2-4-0', (1, 1)))) :     10
# ('oneloc_varyshp', (('V-2-2-0', (-1, 1)), ('V-2-2-0', (-1, -1)))) :     9
# ('oneloc_varyshp', (('V-2-2-0', (-1, 1)), ('V-2-2-0', (1, 1)))) :     10
# ('oneloc_varyshp', (('V-2-2-0', (-1, 1)), ('V-2-4-0', (-1, -1)))) :     9
# ...

# %%
D.seqcontext_preprocess()
D.grouping_print_n_samples(["epoch", "seqc_0_shape", "seqc_0_loc"])

# %%
# Find taskconfigs that occur across multiple epochs
D.epochset_extract_common_epoch_sets(trial_label="taskconfig_shploc",
                                     n_max_epochs=None, merge_sets_with_only_single_epoch=True)
D.Dat["epochset"].value_counts()
# Out:
# Defined new column: epochset
# ... merge_sets_with_only_single_epoch...
# ('singleprim',) only has one epoch!:  ['singleprim']
# Mergin these epochset's ..
# [('singleprim',)]
# Into this new epochset: ('LEFTOVER',)
# -- Final epochsets:
# (oneloc_varyshp, oneshp_varyloc, varyloc_varyshp)    293
# (oneloc_varyshp, varyloc_varyshp)                    115
# (LEFTOVER,)                                           79
# Name: epochset, dtype: int64
# -- FINAL RESULTS (epochset, taskconfig_shploc, epoch):
# (('LEFTOVER',), (('Lcentered-4-3-0', (-1, -1)),), 'singleprim') :     7
# (('LEFTOVER',), (('Lcentered-4-3-0', (-1, 1)),), 'singleprim') :     9
# (('LEFTOVER',), (('Lcentered-4-3-0', (1, 1)),), 'singleprim') :     8
# (('LEFTOVER',), (('V-2-2-0', (-1, -1)),), 'singleprim') :     12
# (('LEFTOVER',), (('V-2-2-0', (-1, 1)),), 'singleprim') :     7
# (('LEFTOVER',), (('V-2-2-0', (1, 1)),), 'singleprim') :     8
# (('LEFTOVER',), (('V-2-4-0', (-1, -1)),), 'singleprim') :     9
# ...

# %%
D.seqcontext_preprocess()
# Out:
# stored in self.Dat[BehClass]
# 0
# 200
# 400
# Running D.behclass_tokens_extract_datsegs
# 0
# 200
# 400
# Appended columns gridsize!

# %%
D.grouping_print_n_samples(["epoch", "seqc_0_shape", "seqc_0_loc"], Nmin=7)
# Out:
# ('oneloc_varyshp', 'Lcentered-4-3-0', (-1, -1)) :     33
# ('oneloc_varyshp', 'Lcentered-4-3-0', (1, 1)) :     29
# ('oneloc_varyshp', 'V-2-2-0', (-1, -1)) :     23
# ('oneloc_varyshp', 'V-2-2-0', (1, 1)) :     29
# ('oneloc_varyshp', 'V-2-4-0', (-1, -1)) :     22
# ('oneloc_varyshp', 'V-2-4-0', (1, 1)) :     27
# ('oneshp_varyloc', 'Lcentered-4-3-0', (-1, -1)) :     28
# ('oneshp_varyloc', 'Lcentered-4-3-0', (1, 1)) :     27
# ('oneshp_varyloc', 'V-2-2-0', (-1, -1)) :     21
# ('oneshp_varyloc', 'V-2-2-0', (1, 1)) :     44
# ('oneshp_varyloc', 'V-2-4-0', (-1, -1)) :     19
# ('oneshp_varyloc', 'V-2-4-0', (1, 1)) :     36
# ('singleprim', 'Lcentered-4-3-0', (-1, 1)) :     9
# ('singleprim', 'Lcentered-4-3-0', (1, 1)) :     8
# ('singleprim', 'V-2-2-0', (-1, -1)) :     12
# ('singleprim', 'V-2-2-0', (1, 1)) :     8
# ('singleprim', 'V-2-4-0', (-1, -1)) :     9
# ('singleprim', 'V-2-4-0', (-1, 1)) :     10
# ('singleprim', 'V-2-4-0', (1, 1)) :     9
# ...

# %%
# Final conjunction for analysis
D.grouping_print_n_samples(["epochset", "epoch", "seqc_0_shape", "seqc_0_loc"])

# %%
D.grouping_print_n_samples(["epoch", "seqc_0_shape", "seqc_0_loc"])

# %% [markdown]
# ##### (2) reassign taskgrops? Simply taskgroups into diff vs. same behavior

# %%
# OPTION 1 - if using matlab sequence, then each task has a single correct seuqence. 
# Can assign tasks unique names like "same_beh"

# %%
D.taskgroup_reassign_ignoring_whether_is_probe(CLASSIFY_PROBE_DETAILED=False, PRINT=True)

# %%
D.grouping_print_n_samples(["taskgroup", "probe"])

# %%
# Option 2 - if using parses for "correct seuquence" then 
# whether is "same_beh" (and in general, labels) depend on 
# what beh monkey actually used.

# here, classify each trial so that (character, seuqence) defines
# a unique beh.

# Find characters that are done with same beh across epochs.

# %% [markdown]
# ##### [USEFUL] check any set of variables for sample size

# %%
var = "seqc_0_loc"
# vars_others = ["epoch", "taskgroup", "seqc_0_shape", "seqc_0_loc"]
# vars_others = ["epoch"]
vars_others = ["epoch"]
# var = "character"
# vars_others = ["epoch"]

# %%
D.grouping_print_n_samples(vars_others + [var], Nmin=7)

# %%
from pythonlib.tools.pandastools import slice_by_row_label
import pandas as pd

df = pd.DataFrame({'A': [5,6,3,4, 5], 'B': [1,2,3,5, 6]})
list_of_values = [4, 3,5, 5, 'test']
# df.set_index('A').loc[list_of_values].reset_index()
display(df)
slice_by_row_label(df, "A", list_of_values, prune_to_value_exist_in_df=True)

# %%
events = ["00_fixcue_-600_to_-50", "00_fixcue_260_to_600", "00_fixcue_40_to_240", 
          "00_fixcue_50_to_600", "03_samp_-600_to_-40", "03_samp_260_to_600"]

# %%
import seaborn as sns
sns.catplot(col_order=)

# %%
from neuralmonkey.analyses.anova_agg_plots import _eventwindow_sort
events_sorted = _eventwindow_sort(events)
events_sorted

# %%
from pythonlib.tools.pandastools import extract_with_levels_of_conjunction_vars, grouping_print_n_samples
df_var, _ = extract_with_levels_of_conjunction_vars(D.Dat, var=var, vars_others=vars_others, n_min=8, PRINT=True,
                                       lenient_allow_data_if_has_n_levels=2, DEBUG=True)

# %%
grouping_print_n_samples(df_var, vars_others + [var], Nmin=5)

# %% [markdown]
# ##### [random sequence tasks] --> finding trials that have sequence matching when this task done in other epochs

# %%
######## PRINT INFO
# D.grouping_print_n_samples(["epochset", "supervision_stage_concise"])
print("-------------")
D.grouping_print_n_samples(["epoch", "supervision_stage_concise"])
print("-------------")
D.grouping_print_n_samples(["epoch", "supervision_stage_new"])

# %%
LIST_SUPERV_NOT_TRAINING = ["off|0||0", "off|1|solid|0", "off|1|rank|0"]
sum(D.Dat["supervision_stage_concise"].isin(LIST_SUPERV_NOT_TRAINING))
# len(D.Dat)

# %%
list_supervision_stage_new = ["mask|0.5|0||0|none",
                              "off|1.0|0||0|none",
                              "off|1.0|0||0|none"]

D.Dat["supervision_stage_new"].value_counts()

# %%
D.grouping_get_inner_items("epoch", "supervision_stage_concise")

# %%
D.grouping_get_inner_items("epoch", "supervision_stage_new")

# %%
D.grouping_get_inner_items("epoch", "supervision_stage_concise")

# %%
D.grouping_get_inner_items("epochset", "supervision_stage_concise")

# %%
D.Dat["supervision_stage_new"].value_counts()

# %%
D.Dat["epoch_color"].value_counts()

# %%
# D.Dat["epoch"].value_counts()
D.Dat["epoch_superv"].value_counts()

# %%
inds = D.Dat[D.Dat["epoch"]=="rndstr"].index.tolist()

# %%
D.sequence_extract_beh_and_task(inds[3], True)

# %%
import numpy as np
np.argsort()

# %% [markdown]
# ##### - merge all color epochs

# %%
D.Dat["epoch_superv"]

# %%
# v1: sequenc emask
Dcopy = D.copy()
print(Dcopy.Dat["epoch_superv"].value_counts())
Dcopy.supervision_epochs_merge_these(
    [("AnBmTR", "mask|0||0"), ("TR", "mask|0||0"), ("rndstr", "mask|0||0")], 
    "rank_mask",
    key = "epoch_superv"
)
Dcopy.Dat["epoch_superv"].value_counts()

# %%
# v2: color rank
D.Dat["epoch"].value_counts()
D.supervision_epochs_merge_these(["rndstr", "llV1|1", "L|1"], "rank|1")
D.Dat["epoch"].value_counts()

# %%
D.Dat["epoch"].value_counts()

# %%
# v2: color rank
D.Dat["epoch"].value_counts()
D.supervision_epochs_merge_these(["rndstr", "AnBmTR|1", "TR|1"], "rank|1", assert_list_epochs_exist=False)
D.Dat["epoch"].value_counts()

# %% [markdown]
# ##### Char_seq --> epochsets, use this for merging color supervision

# %%
D.sequence_char_taskclass_assign_char_seq(ver="task_matlab")
D.Dat["char_seq"].value_counts()

# %%
D.epochset_extract_common_epoch_sets(n_max_epochs=None, merge_sets_with_only_single_epoch=True)
D.Dat["epochset"].value_counts()

# %%
D.grouping_print_n_samples(["epochset", "epoch"])

# %%
# if any epochset_charseq has too few N, then merge it with another one...

# for epochset in list_epochset:
#     n = ...
#     if n < ...:

# %%
#### Plot an example
# D.Dat[D.Dat["epochset_charseq"] == ("AnBmTR|0", "TR|0", "rank|1")].index
D.Dat[D.Dat["epochset_charseq"] == ("AnBmTR|0", "rank|1")].index
# D.Dat[D.Dat["epochset_charseq"] == ("TR|0", "rank|1")].index

D.sequence_extract_beh_and_task(743, True)

# %% [markdown]
# ##### Other stuff [Not working]

# %%
from pythonlib.dataset.modeling.discrete import tasks_categorize_based_on_rule_mult
tasks_categorize_based_on_rule_mult(D)

# %% [markdown]
# ##### If repeat (due to failure) keep only the first trial

# %%
Dcopy = D.copy()
Dcopy.preprocessGood(params = ["remove_repeated_trials"])

# %% [markdown]
# ##### continue stuff

# %%
import numpy as np
np.any(sn._behcode_extract_times(132))

# %%
sn.EventsTimeUsingPhd

# %%
trial = 2
out = sn.events_get_time_using_photodiode(trial, list_events=["rulecue2"], overwrite=True, 
                                    plot_beh_code_stream=True, do_reextract=True)

# %%
for trial in sn.get_trials_list(True, True):
    out = sn.events_get_time_using_photodiode(trial, list_events=["rulecue2"], overwrite=False, 
                                        plot_beh_code_stream=False, do_reextract=False)
    assert len(out["rulecue2"])==1

# %%
# %matplotlib inline
sn.plotwrapper_raster_oneetrial_multsites(trial, [100])

# %%
if ANALY_VER in ["trial_rulesw"]:
    # [GOOD]
    if False:
        D.grammar_successbinary_score_parses()
    else:
        D.grammar_successbinary_score_matlab(True)
elif ANALY_VER in ["trial_seqcontext"]:
    pass
else:
    assert False

# %% [markdown]
# ##### Good, for each task, assign chunks names

# %%
list_epoch = D.Dat["epoch"].unique().tolist()
if len(list_epoch)==1:
    EPOCH = list_epoch[0]
else:
    print(list_epoch)
    assert False, "how deal with this?"

from pythonlib.dataset.modeling.discrete import rules_map_rule_to_ruledict_extract_auto
map_epoch_rulestring = rules_map_rule_to_ruledict_extract_auto(D)
map_epoch_rulestring

# map shapes to their abstract "role"
# epoch = D.Dat.iloc[ind]["epoch_orig"]
ruledict = map_epoch_rulestring[EPOCH]

if ruledict["categ"]=="ss" and ruledict["subcat"]=="rank":
    shapes_in_order_of_roles = ruledict["params_good"]
else:
    shapes_in_order_of_roles = ruledict["params_good"][0]
map_shape_to_rank = {}
for i, shape in enumerate(shapes_in_order_of_roles):
    map_shape_to_rank[shape] = i
print(map_shape_to_rank)

# clean up ranks. They should reflect rank only within the set of shapes that are ever presented otgether
# e.g, if ranks are {'line-8-4-0': 0, 'line-11-1-0': 1, 'line-8-3-0': 2, 'line-11-2-0': 3},
# but line-8 are never presented with line-11, then really want:
# Update shape ranks:  {'line-8-4-0': 0, 'line-11-1-0': 0, 'line-8-3-0': 1, 'line-11-2-0': 1}

list_shape_sets = []
for i in range(len(D.Dat)):
    shapes_used = D.taskclass_shapes_extract(i)
    ADDED = False
    for SET in list_shape_sets:
        if any([sh in SET for sh in shapes_used]):
            # Then at least one shape in shapes_useed is par tof this SET
            ADDED = True
            SET.extend(shapes_used)
    if not ADDED:
        # start a new set
        list_shape_sets.append(shapes_used)
    
    # prune to just unique
    list_shape_sets = [list(set(SET)) for SET in list_shape_sets]

# check that each shape is in a unqque set
this = [xx for x in list_shape_sets for xx in x]
assert len(list(set(this))) == len(this), "bug in code"

print(list_shape_sets)

# for each shape, reassign it a new rank based on only the shapes in its set.
import numpy as np
list_shape_sets_ranks = [[map_shape_to_rank[sh] for sh in SET] for SET in list_shape_sets]
for i, set_idx in enumerate(list_shape_sets_ranks):
    print(set_idx, np.argsort(set_idx))
    list_shape_sets_ranks[i] = np.argsort(set_idx).tolist()
    
# map back the rank to the shape
for i, SET in enumerate(list_shape_sets):
    for j, shape in enumerate(SET):
        rank_within_set = list_shape_sets_ranks[i][j]
        map_shape_to_rank[shape] = rank_within_set
        
print("Updated shape ranks: ", map_shape_to_rank)

# for each trial, determine the chunks, and assign it to each stroke
PLOT = False
for ind in range(len(D.Dat)):
    tokens = D.taskclass_tokens_extract_wrapper(ind, plot=PLOT, return_as_tokensclass=True)
    tokens.chunks_update_by_shaperank(map_shape_to_rank)

# %%
# SANIYT CHECKS
PLOT = True
D = sn.Datasetbeh
D = dataset_pruned_for_trial_analysis
if True:
    ind = 5
    
    D.taskclass_tokens_extract_wrapper(ind, plot=PLOT, return_as_tokensclass=True)

    tok = D.behclass_extract_beh_and_task(ind, include_scale=True)[1]
    print(" ")
    print("CHUNK RANK: ", [t["chunk_rank"] for t in tok])
    print("CHUNK WITHIN RANK:", [t["chunk_within_rank"] for t in tok])

    if False:
        # sanity check that this extract tokens with correct ranks
        tok = D.behclass_extract_beh_and_task(ind)[1]
        print([t["chunk_rank"] for t in tok])
        print([t["chunk_within_rank"] for t in tok])

# %% [markdown]
# ### Extract datstrokes, and for each datstroke note its chunks information

# %%
from pythonlib.dataset.dataset_strokes import DatStrokes
DS = DatStrokes(sn.Datasetbeh)

# %% [markdown]
# ##### Extract sequence context for each stroke

# %%
if ANALY_VER in ["trial_rulesw"]:
    pass
elif ANALY_VER in ["trial_seqcontext", "singleprim"]:
    D = sn.Datasetbeh
    D.behclass_preprocess_wrapper()
    D.seqcontext_preprocess()
else:
    assert False

# %%
D = sn.Datasetbeh
D.behclass_preprocess_wrapper()
D.seqcontext_preprocess()

# %%
# sanity check of extracted sequence params
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 50)
ind = 106
display(D.plot_single_trial(ind))
D.Dat.iloc[ind]

# %% [markdown]
# ##### Extract dataset of good trials.

# %%
display(D.grouping_get_inner_items("epoch", "supervision_stage_concise"))

# %%
preprocess_steps_append = ["one_to_one_beh_task_strokes"]

# %%
from neuralmonkey.classes.snippets import _dataset_extract_prune_general

if ANALY_VER in ["trial_rulesw"]:
    preprocess_steps_append = ["correct_sequencing_binary_score", "one_to_one_beh_task_strokes"]
elif ANALY_VER in ["trial_seqcontext", "singleprim"]:
    preprocess_steps_append = ["one_to_one_beh_task_strokes"]
else:
    assert False

# %%
list_superv_keep = None
# # list_superv_keep = ["off|1|rank|0", "off|0||0", "off|1|solid|0"]
# # preprocess_steps_append = ["correct_sequencing_binary_score", "one_to_one_beh_task_strokes"]
# # preprocess_steps_append = ["correct_sequencing_binary_score", "one_to_one_beh_task_strokes"]
# preprocess_steps_append = ["one_to_one_beh_task_strokes"]
dataset_pruned_for_trial_analysis = _dataset_extract_prune_general(sn, list_superv_keep=list_superv_keep,
                                                                  preprocess_steps_append=preprocess_steps_append)

# %% [markdown]
# ##### Only keep correct trials

# %%
if False:
    # First, compute correct trials
    D.grammar_successbinary_score_parses(True)

    # Second, only keep correct trials.


    ind = 391
    D.sequence_extract_beh_and_task(ind, True)


    D.grammar_successbinary_print_summary()

    D.grammar_successbinary_print_summary()

    D.preprocessGood(params=["correct_sequencing_grammar_parses"])

    gd.parses_extract_generated("ss-rank-AnBm1b")


    ind = 1
    gd = D.grammar_grammardict_return(ind)
    for rule, CLC in gd.ChunksListClassAll.items():
        print(rule)
        CLC.print_summary()

    D.sequence_extract_beh_and_task(ind, True)

# %% [markdown]
# ##### Plot example strokes extracted. Group them by levels of var

# %% [markdown]
# #### [EXTRACTION] STROKES LEVEL

# %%
# Load snippets by hand
import pickle
path = "/gorilla1/analyses/recordings/main/anova/bystroke/Pancho-221014-sess_0/DfScalar.pkl"
with open(path, "rb") as f:
    DfScalar = pickle.load(f)

# %%
# Debug mode
sn._DEBUG_PRUNE_SITES = True
# sn.sitegetter_map_region_to_sites("M1_l")
dataset_pruned_for_trial_analysis.subsampleTrials(10, 1)

# %%
from neuralmonkey.classes.snippets import Snippets, extraction_helper

list_features_modulation_append = ["epoch", "CTXT_loc_prev", "CTXT_shape_prev", "CTXT_loc_next", "CTXT_shape_next", "supervision_stage_concise"]
# list_features_modulation_append = ["CTXT_loc_prev", "CTXT_shape_prev", "CTXT_loc_next", "CTXT_shape_next", "chunk_rank", "chunk_within_rank", "supervision_stage_concise"]
PRE_DUR = -0.6
POST_DUR = 0.6
lenient_allow_data_if_has_n_levels=2
n_min = 5

SP = extraction_helper(sn, "stroke", list_features_modulation_append, 
                       dataset_pruned_for_trial_analysis=dataset_pruned_for_trial_analysis, NEW_VERSION=True, 
                       PRE_DUR = PRE_DUR, POST_DUR = POST_DUR)

SP.globals_update(n_min, lenient_allow_data_if_has_n_levels)

# # Debug, prune sites
# SP.Sites = SP.Sites[::13]
# print("new sites (subsampled): ", SP.Sites)

# %% [markdown]
# #### Trial-level extraction

# %%
sum(dataset_pruned_for_trial_analysis.Dat["trialcode"]=="221020-3-19")

# %%
SAVEDIR = f"/gorilla1/analyses/recordings/main/anova/bytrial/{animal}-{DATE}-sess_{session}"
os.makedirs(SAVEDIR, exist_ok=True)

# %%
from neuralmonkey.classes.snippets import Snippets, extraction_helper

if ANALY_VER in ["trial_rulesw"]:
    list_features_modulation_append = ["probe", "taskgroup", "character", "trialcode", "epoch", "task_kind", "supervision_stage_concise"]
elif ANALY_VER in ["trial_seqcontext"]:
    list_features_modulation_append = ["probe", "taskgroup", "character", "trialcode", "epoch", 
                                       "task_kind", "supervision_stage_concise", 
                                       "seqc_nstrokes_beh", "seqc_nstrokes_task",
                                       "seqc_0_shape", "seqc_0_loc", "seqc_1_shape", 
                                       "seqc_1_loc", "seqc_2_shape", "seqc_2_loc", 
                                       "seqc_3_shape", "seqc_3_loc"]
elif ANALY_VER in ["singleprim"]:
    list_features_modulation_append = ["probe", "taskgroup", "character", "trialcode", "epoch", 
                                       "task_kind", "supervision_stage_concise", 
                                       "seqc_0_shape", "seqc_0_loc"]
else:
    assert False

PRE_DUR = -0.6
POST_DUR = 0.6

SP = extraction_helper(sn, "trial", list_features_modulation_append, 
                       dataset_pruned_for_trial_analysis=dataset_pruned_for_trial_analysis, NEW_VERSION=True, 
                       PRE_DUR = PRE_DUR, POST_DUR = POST_DUR)

SP.save_v2(SAVEDIR)

# %% [markdown]
# ##### Laod DfScalar by hand

# %% [markdown]
# ##### Sanity check plots of raw data extracted by snippets

# %% [markdown]
# #### PLOT ALL

# %%
SitesOrig = SP.Sites

# %%
SP.Sites = SP.Sites[::20]

# %%
SP.Sites = SitesOrig

# %% [markdown]
# ##### make sure no None or nan

# %%
SP.dataextract_as_df_conjunction_vars(var="")

# %%
SP.DfScalar.drop([1,2, 3])

# %%
tmp, _, _ = SP.dataextract_as_df_conjunction_vars(var="seqc_nstrokes_beh", vars_others=["seqc_3_shape"], site = SP.Sites[0])
print(len(tmp))

# %% [markdown]
# ##### Stroke level

# %%
if True:
    SAVEDIR = "/tmp"

var = "epoch"
# vars_conjuction = ['stroke_index', 'gridloc', 'chunk_rank'] # list of str, vars to take conjunction over
# vars_conjuction = ['supervision_stage_concise', 'stroke_index', 'gridloc', 'chunk_rank'] # list of str, vars to take conjunction over
# vars_conjuction = ["supervision_stage_concise", 'stroke_index', 'gridloc', 'chunk_rank', "CTXT_loc_prev"] # list of str, vars to take conjunction over
# vars_conjuction = ['gridloc', 'chunk_rank', 'shape_oriented'] # list of str, vars to take conjunction over
# vars_conjuction = ['gridloc', 'shape_oriented', 'CTXT_loc_prev', 'CTXT_shape_prev', 'CTXT_loc_next', 'CTXT_shape_next'] # list of str, vars to take conjunction over
vars_conjuction = ['gridloc'] # list of str, vars to take conjunction over
PRE_DUR_CALC = -0.25
POST_DUR_CALC = 0.25
# score_ver='fracmod_smfr_minshuff'
# score_ver='r2smfr_zscore'
score_ver = "r2_maxtime_2way_mshuff"

SP.modulationgood_compute_plot_ALL(var, vars_conjuction, score_ver, SAVEDIR=SAVEDIR, 
                                   PRE_DUR_CALC=PRE_DUR_CALC, 
                                   POST_DUR_CALC=POST_DUR_CALC)

# ## HERE is reloaded data, testing if work (sp)
# # sp.modulationgood_compute_plot_ALL(var, vars_conjuction, score_ver, SAVEDIR=SAVEDIR, 
# #                                    PRE_DUR_CALC=PRE_DUR_CALC, 
# #                                    POST_DUR_CALC=POST_DUR_CALC)
# SPall.modulationgood_compute_plot_ALL(var, vars_conjuction, score_ver, SAVEDIR=SAVEDIR, 
#                                PRE_DUR_CALC=PRE_DUR_CALC, 
#                                POST_DUR_CALC=POST_DUR_CALC)

# %% [markdown]
# ##### Trial-level

# %%
if False:
    SP.globals_update(list_events=list_events, list_pre_dur=list_pre_dur, list_post_dur=list_post_dur)
    SP.ParamsGlobals

    # map each event to a 
    SP.ParamsGlobals

    var = "epoch"
    vars_conjuction = ['taskgroup'] # list of str, vars to take conjunction over

    df_var = SP.modulationgood_compute_wrapper(var, vars_conjuction, list_site = SP.Sites[:2])

    # jt -t oceans16 -f roboto -fs 12 -cellw 100%

    _, levs_df, levels_var = SP.dataextract_as_df_conjunction_vars(var, vars_conjuction, SP.Sites[0], event="00_fix_touch")


    for k, v in levs_df.items():
        print(k, len(v))
        ms = SP._dataextract_as_metrics_scalar(v, var)

# %%
SP.DfScalar["supervision_stage_concise"].value_counts()

# %%
SP.DfScalar

# %%
from pythonlib.tools.exceptions import NotEnoughDataException
if True:
    SAVEDIR = "/tmp"

# var = "epoch"
# vars_conjuction = ['taskgroup'] # list of str, vars to take conjunction over
# var = "seqc_nstrokes_beh"
# vars_conjuction = ["seqc_0_shape", "seqc_1_shape", "seqc_2_shape", "seqc_3_shape"] # list of str, vars to take conjunction over
var = "seqc_0_shape"
vars_conjuction = ["seqc_0_loc"] # list of str, vars to take conjunction over

# PRE_DUR_CALC = -0.25
# POST_DUR_CALC = 0.25
PRE_DUR_CALC = None
POST_DUR_CALC = None
score_ver='fracmod_smfr_minshuff'
# score_ver='r2smfr_running_maxtime_oneway'
# score_ver='r2smfr_zscore'
list_events = ["01_fix_touch", "02_samp", "04_first_raise"]
list_pre_dur = [-0.5, 0.05, -0.1]
list_post_dur = [-0, 0.6, 0.5]
globals_nmin=1
globals_lenient_allow_data_if_has_n_levels=1
try:
    SP.modulationgood_compute_plot_ALL(var, vars_conjuction, score_ver, SAVEDIR=SAVEDIR, 
                                       PRE_DUR_CALC=PRE_DUR_CALC, 
                                       POST_DUR_CALC=POST_DUR_CALC,
                                      list_events=list_events, list_pre_dur=list_pre_dur, 
                                       list_post_dur=list_post_dur, DEBUG_CONJUNCTIONS=False,
                                      globals_nmin=globals_nmin,
                                    globals_lenient_allow_data_if_has_n_levels=globals_lenient_allow_data_if_has_n_levels)
except NotEnoughDataException as err:
    print(err)
# ## HERE is reloaded data, testing if work (sp)
# # sp.modulationgood_compute_plot_ALL(var, vars_conjuction, score_ver, SAVEDIR=SAVEDIR, 
# #                                    PRE_DUR_CALC=PRE_DUR_CALC, 
# #                                    POST_DUR_CALC=POST_DUR_CALC)
# SPall.modulationgood_compute_plot_ALL(var, vars_conjuction, score_ver, SAVEDIR=SAVEDIR, 
#                                PRE_DUR_CALC=PRE_DUR_CALC, 
#                                POST_DUR_CALC=POST_DUR_CALC)

# %%
from neuralmonkey.metadat.analy.anova_params import params_getter

params_getter(animal, DATE, which_level, ANALY_VER)

# %%
SP.modulationgood_aggregate_df(df_var)

# %%
dfvar = SP.modulationgood_compute_wrapper(var, vars_conjuction, score_ver=score_ver, get_z_score=True, list_events=[event])

# %%
SP.modulationgood_plot_each_chan(dfvar, var, vars_conjuction)

# %%
SP.modulationgood_compute_wrapper(var, vars_conjuction, score_ver=score_ver, get_z_score=True, event=event)

# %%
df_fr, df_fr_levels = SP.modulationgood_compute_fr_quick(var)
# df_fr = df_fr[df_fr["event_aligned"] == event]

# %%
import seaborn as sns
fig = sns.catplot(data=df_fr, x="event", y="val", hue="val_kind",
                  col="bregion", col_wrap=4, kind="point", aspect=1, height=3);

# %% [markdown]
# ##### Testing - specific ploits within PLOT ALL

# %%
df_var = SP.modulationgood_compute_wrapper(var, vars_conjuction, score_ver=score_ver)

# %%
vars_conjuction

# %%
df_var

# %%
from pythonlib.tools.pandastools import aggregGeneral

df_var_agg = aggregGeneral(df_var, group=["chan", "event", "var", "var_others", "val_kind", "val_method"], values = ["val"], 
              nonnumercols=["bregion"])

# %%
# modulation, plot
SP.modulationgood_plot_summarystats(df_var)

# %%
# Plot smoothed fr under rasters
SP.plot_smfr_average_each_level(SP.Sites[0])

# %%
dfthis["fr_sm"].tolist()[0].shape

# %%
dfthis["fr_sm"].tolist()

# %%
# 2) make a popanal wit
import numpy as np

# PARAMS
site = SP.Sites[0]
# var = "shape_oriented"
# vars_conjuction
var = "chunk_within_rank"
vars_conjuction = ['supervision_stage_concise', 'stroke_index', 'gridloc', 'chunk_rank'] # list of str, vars to take conjunction over
time_take_first = True

# 1) extract fr
PA = SP.dataextract_as_popanal(var, vars_conjuction, site)
    
# 3) plot
# %matplotlib inline
SP.__plotgood_smoothfr_average_each_level()

# %%
vars_others = ['stroke_index']

# %%
site = SP.Sites[0]
SP.dataextract_as_popanal_conjunction_vars(var, vars_conjuction, site=site)[0].keys()

# %% [markdown]
# ##### Plot overlaying rasters and sm fr

# %%
SP.plotgood_rasters_smfr_each_level_combined(SP.Sites[-1], var, vars_others);

# %% [markdown]
# ##### Automatically check possible combinations of var and vars_conjunction

# %%
# vars_check = ["epoch", "", "gridloc", "shape_oriented", "chunk_rank", "chunk_within_rank"]
vars_check = ["seqc_nstrokes_beh", "seqc_0_shape", "seqc_0_loc", "task_kind"]
SP.modulationgood_plot_list_conjuctions(vars_check, SAVEDIR)

# %% [markdown]
# ##### Other

# %%
dfout = SP.modulationgood_compute_wrapper(var, vars_conjuction, score_ver=score_ver)
df_fr, df_fr_levels = SP.modulationgood_compute_fr_quick(var)


var = "chunk_within_rank"
vars_conjuction = ['stroke_index', 'gridloc', 'chunk_rank'] # list of str, vars to take conjunction over
SP.plotgood_rasters_split_by_feature_levels_grpbyothervar(SP.Sites[0], var, vars_conjuction)

# %% [markdown]
# ##### DEbug somethng

# %%
os.path.exists(path)

# %%
path = "/gorilla1/analyses/recordings/main/anova/bytrial/MULT_SESS/Pancho-221121-0_1_2_3/rulesw/var_by_varsother/VAR_epoch-OV_taskgroup_probe/SV_r2_maxtime_1way_mshuff/df_var.pkl"

# %%
# path = "/gorilla1/analyses/recordings/main/anova/bytrial/MULT_SESS/OLD_230515/Pancho-221020-0_1/var_by_varsother/VAR_epoch-OV_taskgroup/SV_r2_maxtime_1way_mshuff/df_var.pkl' '/gorilla1/analyses/recordings/main/anova/bytrial/MULT_SESS/OLD_230515/Pancho-221020-0_1/var_by_varsother/VAR_probe-OV_seqc_0_loc_seqc_0_shape_epoch/SV_r2_maxtime_1way_mshuff/df_var.pkl"
import pickle
with open(path, "rb") as f:
    df_var = pickle.load(f)

# %%
df_var["event"]

# %%
path = "/gorilla1/analyses/recordings/main/anova/bytrial/MULT_SESS/Pancho-221121-0_1_2_3/rulesw/var_by_varsother/VAR_epoch-OV_taskgroup_probe/SV_r2_maxtime_1way_mshuff/list_eventwindow_event.pkl"
import pickle
with open(path, "rb") as f:
    list_eventwindow_event = pickle.load(f)

# %%
list_eventwindow_event

# %% [markdown]
# ##### Extract already-processed events from saved df_var

# %%
events_done = [x[0] for x in list_eventwindow_event]
events_done

# %%
import pandas as pd
pd.concat()

# %% [markdown]
# ##### Other stuff

# %%
SPall.modulationgood_aggregate_df(df_var)

# %%
SPall.modulationgood_plot_summarystats(df_var)

# %%
SPall.modulationgood_plot_twoway_summary(df_var, "/tmp")

# %%
from pythonlib.tools.pandastools import aggregGeneral
var_other_single = "taskgroup"
df_var_agg = aggregGeneral(df_var, group=["chan", "event", "var", "var_others", "val_kind", "val_method", var_other_single], 
              values = ["val"], 
              nonnumercols=["bregion"])

# %% [markdown]
# ##### 2)  Print conjunctions that exist

# %%
site = 139
score_ver = "fracmod_smfr_minshuff"
# score_ver = "r2smfr_minshuff"
# score_ver = "r2smfr_zscore"
# var = "chunk_within_rank"
var = "gridloc"
vars_conjuction = ['shape_oriented', 'CTXT_loc_prev', 'CTXT_shape_prev', 'CTXT_loc_next', 'CTXT_shape_next']
SPall.plotgood_rasters_smfr_each_level_combined(site, var, vars_conjuction)

SPall.modulationgood_compute_wrapper(var, vars_conjuction, list_site=[site], score_ver=score_ver)

# %%
SPall.dataextract_as_df_conjunction_vars(var, vars_conjuction, site)

# %%
SPall.modulationgood_compute_plot_ALL(var, vars_conjuction)
# sp.modulationgood_compute_plot_ALL(var, vars_conjuction)

# %%
# # Things that need SN for.

# # region = self.SN.sitegetter_map_site_to_region(x["chan"])
# #                     fig.savefig(f"{sdir}/{self.SN.sitegetter_summarytext(site)}.png")
# #         fig, ax, kwargs = self.SN._plot_raster_create_figure_blank(dur, len(dfthis), nrows, ncols)
        
#         self.SN._plot_raster_line_mult(ax, list_spiketimes, ylabel_trials=trials)
#         self.SN.plotmod_overlay_trial_events_mult(ax, trials, event_times, xmin=xmin, xmax=xmax)
        
        
# # CHECK THESE BELOW
#         self.SN.plot_raster_spiketimes_blocked(ax, list_list_st, list_labels, list_list_trials, 
#             list_list_evtimes, xmin = xmin, xmax=xmax)

#                     trials_sn = self.SN.datasetbeh_trialcode_to_trial_batch(list_trialcode)

# %% [markdown]
# ##### Plot brain schematic

# %%
SPall.DfScalar["task_kind"].value_counts()

# %%
SPall.modulationgood_plot_brainschematic(df_var, "/tmp")

# %% [markdown]
# ##### Plotting rasters combined across datasets

# %%
from neuralmonkey.metadat.analy.anova_params import params_getter_plots
params_getter_plots("Pancho)

# %%
grp = ["task_kind", "epoch"]
len(SPall.DfScalar.groupby(grp))

# %%
LIST_SUPERV_NOT_TRAINING = ["off|0||0", "off|1|solid|0", "off|1|rank|0"]
indskeep = SPall.DfScalar["supervision_stage_concise"].isin(LIST_SUPERV_NOT_TRAINING)
SPall.DfScalar = SPall.DfScalar[indskeep].reset_index(drop=True)

# %%
SPall.DfScalar

# %%
## DEBUG
sp.ParamsGlobals = {'n_min_trials_per_level': 5, 'lenient_allow_data_if_has_n_levels': 2}

sp.ParamsGlobals["n_min_trials_per_level"] = 2

sp.SN.plotwrapper_raster_multrials_onesite([37, 38, 41, 49], site, alignto="on_strokeidx_3")

sp = list_sp[0]
var = "chunk_within_rank"
vars_others = ['stroke_index', 'gridloc', 'chunk_rank', 'CTXT_loc_prev', 'CTXT_shape_prev', 'supervision_stage_concise']
site = 329
sp.plotgood_rasters_smfr_each_level_combined(site, var, vars_others);



var = "chunk_within_rank"
vars_others = ['stroke_index', 'gridloc', 'chunk_rank', 'CTXT_loc_prev', 'CTXT_shape_prev', 'supervision_stage_concise']
site = 329
SPall.plotgood_rasters_smfr_each_level_combined(site, var, vars_others);

# %% [markdown]
# ### New metric that normalizes to fr

# %%
sp = SPall
site = sp.Sites[65]
site= 460

# var = "stroke_index"
# vars_others = ["gridloc", "shape_oriented", "CTXT_loc_prev", "CTXT_shape_prev", "CTXT_loc_next"]

var = "chunk_within_rank"
vars_others = ["stroke_index", "gridloc", "chunk_rank", "CTXT_loc_prev", "CTXT_shape_prev"]

_, dict_lev_df, levels_var = sp.dataextract_as_df_conjunction_vars(var, vars_others, site)

sp.plotgood_rasters_smfr_each_level_combined(site, var, vars_others);


# scorever = 
scores = []
for lev, dfthis in dict_lev_df.items():
    print("------")
    print(lev, len(dfthis))
    ms = sp._dataextract_as_metrics_scalar(dfthis, var=var)
    this = ms.modulationgood_wrapper_(var, "fracmod_smfr_minshuff")
    scores.append(this["00_stroke"])

print(scores)
print(np.mean(scores))

# %% [markdown]
# #### [good] summarize dataset more carefully

# %%
# Modulation
# - modulation vs. zscore.
# - modulation = weighted average over all subgroupings.

# sites = SPall.Sites[:10]
sites = SPall.Sites
score_ver = "fracmod_smfr_minshuff"
dfout = SPall.modulationgood_compute_wrapper(var, vars_others, list_site = sites, score_ver=score_ver,
                                            get_z_score=True)

# %% [markdown]
# ##### Plots

# %%
savedir = "/tmp"
score_ver

# %%
SPall.modulationgood_compute_plot_ALL(var, vars_others, score_ver=score_ver)

# %% [markdown]
# ##### Plot rasters and compute score for a single site.

# %%
SPall.plotgood_rasters_smfr_each_level_combined(96, var, vars_others)
# SPall.modulationgood_compute_wrapper(var, vars_others, list_site=[96], score_ver=score_ver)
SPall.modulationgood_compute_wrapper(var, vars_others, list_site=[96], score_ver="r2smfr_zscore")

# %% [markdown]
# ##### ANOVA, using new version of SP

# %% [markdown]
# ##### ANOVA

# %%
# Testing out old anova code.
THINGS_TO_COMPUTE = ["modulation"]
RES_ALL_CHANS = SP.modulation_compute_each_chan(things_to_compute=THINGS_TO_COMPUTE)
OUT = SP.modulation_compute_higher_stats(RES_ALL_CHANS)

# %%
SAVEDIR_SCALAR = "/tmp"
SAVEDIR_SCALAR

# %%
if True:
    # LIST_PLOTS = ['eachsite_rasters'] # FAILED
#     LIST_PLOTS = ['eachsite_smfr'] # PASSED
    LIST_PLOTS = ['eachsite_allvars'] # PASSED
    # LIST_PLOTS = ['eachsite_smfr_splitby_character'] # FAILED
    SP.modulation_plot_all(RES_ALL_CHANS, OUT, SAVEDIR_SCALAR, list_plots=LIST_PLOTS)



# PASSED!
if False:
    SP.modulation_plot_all(RES_ALL_CHANS, OUT, SAVEDIR_SCALAR, list_plots=["summarystats", "heatmaps"], 
                           which_modulation_variable = "modulation_across_events_usingsmfr_zscored",
                           which_var_heatmaps = "modulation_across_events_usingsmfr_zscored")
    
#     SP.modulation_plot_all(RES_ALL_CHANS, OUT, SAVEDIR_SCALAR, list_plots=["summarystats", "heatmaps"], 
#                            which_modulation_variable = "modulation_across_events_usingsmfr",
#                            which_var_heatmaps = "modulation_across_events_usingsmfr")

# %%
### [TODO] EVENTS MODULATION PLOTS
# not as important. it is already concise. see the code.
from neuralmonkey.analyses.event_temporal_modulation import preprocess_and_plot, plot_overview
SP_trial, SP_stroke, Mscal, df_modtime = preprocess_and_plot(MS, SAVEDIR, session=session, DEBUG=False)

# %%
### RASTER PLOTS
# TODO

# %%
#### TODO (merging the code)
# 1) Run the above using using data=trials
# 2) easier code (celan up)
# 3) rasters, use rasters saved in SP
# --> replaces eachsite_rasters in SP plots

#### TODO, sciecne
# 1. Modulation by one variable, conditioned on specific level of other variable
# -- see eachsite_allvars, have to get this working, it does it.

# %% [markdown]
# ##### Plot each chan

# %%
# TODO

# %% [markdown]
# ##### TODO:

# %%
# - make generic plotting code for modulation.
# - plot, for chunks.
# - 2d plot of all variable conjunctions (count, scores)

# %% [markdown]
# ### [OLD, from Event_temporal...]

# %% [markdown]
# ##### Extract single snippet for each stroke

# %%
from neuralmonkey.analyses.event_temporal_modulation import preprocess_and_plot, plot_overview

# DEBUGGIN


SP_trial, SP_stroke, Mscal, df_modtime = preprocess_and_plot(MS, SAVEDIR, session=session, DEBUG=True)

# %%
# GOOD
for session in range(len(MS.SessionsList)):
    
    SAVEDIR = f"/gorilla1/analyses/recordings/main/events_modulation/{animal}-{DATE}-sess_{session}"
    os.makedirs(SAVEDIR, exist_ok=True)
    
    SP_trial, SP_stroke, Mscal, df_modtime = preprocess_and_plot(MS, SAVEDIR, session=session, DEBUG=True)

# %%
# DEBUGGING
if False:
    plot_overview(df_modtime, SAVEDIR)

# %% [markdown]
# ### LOAD DIRECTLY the results of above, and make plots

# %%
import os
import pickle

SAVEDIR = "/gorilla1/analyses/recordings/main/events_modulation/Pancho-221020-sess_0/RELOADED_DF_MODTIME"
path = "/gorilla1/analyses/recordings/main/events_modulation/Pancho-221020-sess_0/df_modtime.pkl"

# SAVEDIR = "/gorilla1/analyses/recordings/main/events_modulation/Pancho-221107-sess_0/RELOADED_DF_MODTIME"
# path = "/gorilla1/analyses/recordings/main/events_modulation/Pancho-221107-sess_0/df_modtime.pkl"

os.makedirs(SAVEDIR, exist_ok=True)

with open(path, "rb") as f:
    df_modtime = pickle.load(f)

from neuralmonkey.analyses.event_temporal_modulation import plot_overview
plot_overview(df_modtime, SAVEDIR)

# %%
#### Load MScal
path = "/gorilla1/analyses/recordings/main/events_modulation/Pancho-221020-sess_0/Mscal.pkl"
with open(path, "rb") as f:
    Mscal = pickle.load(f)

# %%
import numpy as np
event_stroke_all_tuple = ("stroke-last", "stroke-first", "stroke-both_fl", "stroke-middle")
list_event_get = Mscal.ListEventsUniqname + [event_stroke_all_tuple]
list_event_get = [ev for ev in list_event_get if not ev=="stroke-both_fl"]
res = Mscal.modulationbytime_calc_this(1, list_event_get)

x = [r["r2_time"] for r in res]

# plt.figure()
# plt.plot(x)
print("MEAN r2:", np.mean(x))
for xx in x:
    print(xx)

# %%
list_site_good = Mscal.Data["chan"].unique().tolist()

# %%
res

# %%
res

# %%
res_all = []
event_stroke_all = ("stroke-last", "stroke-first", "stroke-middle")
list_event_get = Mscal.ListEventsUniqname + [event_stroke_all]

for site in list_site_good:

    if site%20==0:
        print(site)

    # 1) Compute matrix for trial-level data
    res_this = Mscal.modulationbytime_calc_this(site, list_event=list_event_get)
    res_all.extend(res_this)

df_modtime = pd.DataFrame(res_all)
df_modtime["event_var_level"] = df_modtime["event"]

# %% [markdown]
# ##### Combine multiple days (each unit is independent)

# %%
import os
import pickle
from neuralmonkey.analyses.event_temporal_modulation import preprocess_and_plot, plot_overview

# %%
# do_recompute = True
# list_date_sess = [
#     (220616, 0),
#     (220630, 0),
#     (221020, 0),
# ]

do_recompute = True
list_date_sess = [
    (220616, 0),
    (220630, 0),
    (220624, 0),
    (220714, 0),
    (220827, 0),
    (221020, 0), 
    (221107, 0)
]

list_df_modtime = []
for date, sess in list_date_sess:
    path = f"/gorilla1/analyses/recordings/main/events_modulation/Pancho-{date}-sess_{sess}/df_modtime.pkl"
    with open(path, "rb") as f:
        df_modtime = pickle.load(f)
    
    # RECOMPUTE for this day?
    if do_recompute:
        SAVEDIRTHIS = f"/gorilla1/analyses/recordings/main/events_modulation/Pancho-{date}-sess_{sess}/RELOADED_DF_MODTIME"
        os.makedirs(SAVEDIRTHIS, exist_ok=True)
        plot_overview(df_modtime, SAVEDIRTHIS)

    # append the file
#     df_modtime["date_sess"] = (date, sess)
    df_modtime["date_sess"] = f"{date}-{sess}"
    
    # store
    list_df_modtime.append(df_modtime)

# %%
# concat
import pandas as pd
df_modtime_all = pd.concat(list_df_modtime).reset_index(drop=True)

# rename site so that is cross of site x session
from pythonlib.tools.pandastools import applyFunctionToAllRows
def F(x):
    return f"{x['date_sess']}-{x['site']}"
df_modtime_all = applyFunctionToAllRows(df_modtime_all, F, "site")

# remove site_region, so not get confused
df_modtime_all = df_modtime_all.drop("site_region", axis=1)

# %%
from pythonlib.tools.expttools import makeTimeStamp, writeDictToYaml
ts = makeTimeStamp()

# %%
# save combined data
sdir = f"/gorilla1/analyses/recordings/main/events_modulation/COMBINED/{ts}"
os.makedirs(sdir, exist_ok=True)

# save info
writeDictToYaml(list_date_sess, f"{sdir}/list_date_sess.txt")

# %%
# Plot
plot_overview(df_modtime_all, sdir)

# %%
from neuralmonkey.analyses.event_temporal_modulation import kernel_compute, _kernel_compute_scores_pos_and_neg

df_kernels, df_modtime_wide, df_modtime_wide_normrowsubtr, dict_kernels = kernel_compute(df_modtime_all, normalize_by_row=False)

# %%
sns.catplot(data=df_kernels, x="region", y="kernel_score", col="kernel_id", col_wrap=4, )

# %%
for kernel, weights in dict_kernels.items():
    scores_pos, scores_neg = _kernel_compute_scores_pos_and_neg(df_modtime_wide, kernel, weights)

# %%
df_modtime_wide

# %%
region = "FP_a"
dfthis = df_modtime_wide[df_modtime_wide["region"]==region]
scores_pos, scores_neg = _kernel_compute_scores_pos_and_neg(dfthis, kernel, weights)

fig, ax = plt.subplots()
# ax.plot(scores_pos, scores_neg, 'xk')
from pythonlib.tools.plottools import plotScatter45
plotScatter45(scores_pos, scores_neg, ax=ax, means=True)

# %%
import pingouin as pg
kernel = ('stroke-first',
  'stroke-middle',
  'stroke-last',
  '00_fix_touch',
  '05_doneb')
weights = dict_kernels[kernel]

res = []
for region in df_modtime_wide["region"].unique().tolist():
#     region = "FP_p"
    dfthis = df_modtime_wide[df_modtime_wide["region"]==region]
    scores_pos, scores_neg = _kernel_compute_scores_pos_and_neg(dfthis, kernel, weights)
    
    if False:
        fig, ax = plt.subplots()
        # ax.plot(scores_pos, scores_neg, 'xk')
        from pythonlib.tools.plottools import plotScatter45
        plotScatter45(scores_pos, scores_neg, ax=ax, means=True)
    
    
    # linear regression    
    stats = pg.linear_regression(scores_pos, scores_neg, add_intercept=False)
    res.append({
        "region":region,
        "stats":stats
    })

# %%
list_coef = [r["stats"].coef.item() for r in res]
list_se = [r["stats"].se.item() for r in res]
list_region = [r["region"] for r in res]

fig, ax = plt.subplots()
ax.errorbar(x = range(len(list_region)), y=list_coef, xerr=list_se, yerr=list_se)
# ax.bar(range(len(list_region)), list_coef, xerr=list_se, yerr=list_se)
ax.set_xticks(range(len(list_region)), list_region);
from pythonlib.tools.plottools import rotate_x_labels
rotate_x_labels(ax, 45)

# %% [markdown]
# ##### Debug single day

# %%
# Plot heatmap of scores, ordering brain areas by eye/hand... IN PROGRESS
from neuralmonkey.neuralplots.brainschematic import regions_get_ordered_by_x
list_col1 = regions_get_ordered_by_x()
print(list_col1)

# %%
list_col2 = [
    
]

# %%
norm_method = "row_sub"
val_name = "r2_time_minusmean"

# 1) Plot summary (mean over sites)
fig, ax = plt.subplots(1,1, figsize=(8,8))
convert_to_2d_dataframe(df_modtime, col1="region", col2="event_var_level", plot_heatmap=True, 
                        agg_method="mean", val_name=val_name, annotate_heatmap=False, ax=ax, 
                       norm_method=norm_method, dosort_colnames =False,list_cat_1=list_col1);

assert False

# %%
from neuralmonkey.analyses.event_temporal_modulation import kernel_compute, _kernel_compute_scores
df_kernels, df_modtime_wide, df_modtime_wide_normrowsubtr, dict_kernels = kernel_compute(df_modtime)

# %%
response='r2_time_minusmean'
from pythonlib.tools.plottools import plotScatterXreduced, plotScatterOverlay
overlay_mean = False

# %%
sdirthis

# %% [markdown]
# #### SMOOTHED FR, ALIGNED TO EACH EVENT, FOR EACH UNIT

# %%
sdir = f"{SAVEDIR}/smfr_relative_strokes"
os.makedirs(sdir, exist_ok=True)


SP_stroke.plot_smfr_average_each_level(13, list_var=["stroke_index_semantic"])


SP_stroke.plot_rasters_smfr_each_level_combined(500, "epoch");

if False:
    import random
    site = random.sample(SP.Sites, 1)[0]
    SP.plot_smfr_average_each_level(site, list_var=["ind_taskstroke_orig"], list_events_uniqnames=["00_stroke"])
    sn.sitegetter_summarytext(site)

# %% [markdown]
# ##### Plot as heat map, showing all the units

# %%
# DS.timing_extract_basic()
# DS.Dat

# %%
fig, ax = plt.subplots()
ax.hist(DS.Dat["time_duration"], 20)

# %% [markdown]
# ##### Plot, Heat map of (unit vs event), for each brain region

# %%
sn = MS.SessionsList[0]
import random

# %%
# Plot example sites
SP_trial.plot_smfr_average_each_level(chan=6, list_var=["stroke_index"])

# %%
site = 451
trial = 100
fig, ax = plt.subplots(1,1, figsize=(15,2))
sn.plotwrapper_smoothed_multtrials_multsites([site], [trial], ax=ax)
sn.plot_raster_trials(ax, [trial], site, overlay_trial_events=False)

# %% [markdown]
# ##### Example rasters

# %%
# List the exmaples (Wang lab meeting 3/22/23)
# for 10/20/23, sess 0
SAVEDIR

# %%
sn = MS.SessionsList[session]

SAVEDIR
sdir = f"{SAVEDIR}/example_rasters_smfr"
os.makedirs(sdir, exist_ok=True)
print(sdir)

# %%
# Plot a single raster
site = 332
alignto = "post"
sn.plotwrapper_raster_multrials_onesite(trials, site=site, alignto=alignto, plot_beh=False);

# %%
## Visual vs. motor
# list_site = [302, 307, 441, 31]
# list_alignto = ["samp", "first_raise"]

# stroke vs. other movement
# list_site = [451, 469, 465, 53, 57, 97]
# list_alignto = ["fix_touch", "on_strokeidx_0", "doneb"]

# FP (go cue and post)
list_site = [334, 332]
list_alignto = ["go", "post"]

# alignto = "samp"
# alignto = "first_raise"
# alignto = "on_strokeidx_0"

###########
trials = sn.get_trials_list(True, True, True, events_that_must_include=[alignto])
trials = sorted(random.sample(trials, 20))

# 1) Plot rasters
for site in list_site:
    for alignto in list_alignto:        
        fig, axes, fig_draw, axes_draw = sn.plotwrapper_raster_multrials_onesite(trials, site=site, alignto=alignto, plot_beh=False);
        fig.savefig(f"{sdir}/raster_site_{site}-alignto_{alignto}-multtrials.pdf")

# 2) Plot smoothed fr
fig, axes = plt.subplots(len(list_site), len(list_alignto), sharex=True, sharey="row",
                        figsize=(len(list_alignto)*3, len(list_site)*3))
for i, site in enumerate(list_site):
    for j, alignto in enumerate(list_alignto):
            
        ax = axes[i][j]
        sn.plotwrapper_smoothed_multtrials_multsites_timewindow([site], trials, alignto=alignto, pre_dur=-0.4, 
                                                                post_dur=0.4, ax=ax)
        ax.set_title(alignto)
        ax.set_ylabel(site)
        
fig.savefig(f"{sdir}/smfr-site_{list_site[0]}_to_{list_site[-1]}.pdf")

# %% [markdown]
# ## Metric to quantify modulation relative to events

# %%
def _extract_frmat_chan_event(SPthis, chan, event, var=None, var_level=None):
    """ 
    Extract frmat, stacking all instances of this event.
    Can optionally keep only this level for this var
    """
    assert False, "use SP.dataextract_as_frmat"
    assert (var_level==None) == (var==None)
    
    if var_level is not None:
        dfthis = SPthis.DfScalar[(SPthis.DfScalar["chan"]==chan) & (SPthis.DfScalar["event_aligned"]==event) & (SPthis.DfScalar[var]==var_level)]   
    else:
        dfthis = SPthis.DfScalar[(SPthis.DfScalar["chan"]==chan) & (SPthis.DfScalar["event_aligned"]==event)]    
        
    frmat = np.concatenate(dfthis["fr_sm"].tolist(), axis=0)    
    
    return frmat

# %%
site = 79
alignto = "01_go"
event="go"
frmat = _extract_frmat_chan_event(site, alignto)

# %%
# Plot overlay of multiple trials smoothed fr
fig, ax = plt.subplots(1,1, figsize=(5,2))
trials = SP.Trials[:25]
pre_dur=-0.8
post_dur=0.8
sn.plotwrapper_smoothed_multtrials_multsites_timewindow([site], trials, event, pre_dur, post_dur, ax=ax, 
                                                        plot_summary=True)

# %%
sdir = f"{SAVEDIR}/smfr_relative_strokes"
    os.makedirs(sdir, exist_ok=True)

    SP_stroke.plot_smfr_average_each_level(13, list_var=["stroke_index_semantic"])


    SP_stroke.plot_rasters_smfr_each_level_combined(500, "epoch");

# %% [markdown]
# ##### Plots of modulation

# %%
dfthis = df_modtime

# %%
from pythonlib.tools.snstools import rotateLabel
fig = sns.catplot(data=dfthis, x="event", y="r2_time", hue="region", kind="point", ci=68)
rotateLabel(fig)

# %%
fig = sns.catplot(data=dfthis, x="event", y="r2_time", hue="region", kind="bar")

# %%
fig = sns.catplot(data=dfthis, x="event", col="region", col_wrap=3, y="r2_time_zscored", kind="point", ci=68)
# fig = sns.catplot(data=dfthis, x="event", col="region", col_wrap=3, y="r2_time_zscored")
rotateLabel(fig)

# %%
# DEBUGGING

Mscal.modulationbytime_calc_this(57)

from neuralmonkey.metrics.scalar import _calc_modulation_by_frsm_event_aligned_time



frmat = Mscal.dataextract_as_frmat(57, "stroke-first")
print(frmat.shape)
r2 = _calc_modulation_by_frsm_event_aligned_time(frmat)
print(r2)
fig, ax = plt.subplots(1,1)
ax.plot(frmat.T);

frmat = Mscal.dataextract_as_frmat(57, "stroke-last")
print(frmat.shape)
r2 = _calc_modulation_by_frsm_event_aligned_time(frmat)
print(r2)
fig, ax = plt.subplots(1,1)
ax.plot(frmat.T);

# %%
# fig = sns.catplot(data=dfthis, x="region", col="event", col_wrap=3, y="r2_time", kind="point", ci=68)
fig = sns.catplot(data=dfthis, x="region", hue="event", y="r2_time", kind="point", ci=68, aspect=2)
rotateLabel(fig)
