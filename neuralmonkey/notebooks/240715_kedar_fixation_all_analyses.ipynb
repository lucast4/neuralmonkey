# %%
"""
6/4/25 -- GOOD This holds or links to the most recent eye fixation related plots
LT 7/15/24 - Porting all kedar here, about activity aligned to fixation events.

"""
# Out:
# '\n6/4/25 -- GOOD This holds or links to the most recent eye fixation related plots\nLT 7/15/24 - Porting all kedar here, about activity aligned to fixation events.\n\n'

# %%
from neuralmonkey.classes.population_mult import load_handsaved_wrapper, dfpa_match_chans_across_pa_each_bregion
from neuralmonkey.classes.population_mult import extract_single_pa
import os
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
# Method 1 - load a single DFallPA


# animal = "Pancho"
# date = 230626

# animal = "Diego"
# date = 240625

animal = "Diego"
date = 230615

which_level = "saccade_fix_on"
combine_areas = True
question = "PIG_BASE_saccade_fix_on"
DFallpa = load_handsaved_wrapper(animal=animal, date=date, version=which_level, combine_areas=combine_areas, question=question)
# Out:
# Loading DFallpa from:  /lemur2/lucas/Dropbox/SCIENCE/FREIWALD_LAB/DATA/Xuan/DFallpa-Diego-230615-saccade_fix_on-kilosort_if_exists-norm=None-combine=True-t1=-0.4-t2=0.4-quest=PIG_BASE_saccade_fix_on.pkl

# %%
# Load recen

# %%
### PREPROCESS
from neuralmonkey.classes.population_mult import dfpa_concatbregion_preprocess_clean_bad_channels, dfpa_concatbregion_preprocess_wrapper
dfpa_concatbregion_preprocess_wrapper(DFallpa, animal, date)

# dfpa_concatbregion_preprocess_clean_bad_channels(DFallpa, PLOT=False)

# for pa in DFallpa["pa"]:
#     pa.X = pa.X**0.5

# from neuralmonkey.classes.population_mult import dfallpa_preprocess_fr_normalization
# # fr_normalization_method = "each_time_bin"
# fr_normalization_method = "across_time_bins"
# plot_savedir = "/tmp"
# dfallpa_preprocess_fr_normalization(DFallpa, fr_normalization_method, plot_savedir)
# Out:
#  == (1) Matching chans across events
# M1  ...  43
# M1  -- n chans final:  43
# PMv  ...  68
# PMv  -- n chans final:  68
# PMd  ...  36
# PMd  -- n chans final:  36
# dlPFC  ...  24
# dlPFC  -- n chans final:  24
# vlPFC  ...  54
# vlPFC  -- n chans final:  54
# FP  ...  35
# FP  -- n chans final:  35
# SMA  ...  51
# SMA  -- n chans final:  51
# preSMA  ...  66
# preSMA  -- n chans final:  66
#  == (2) Remove bad chans based on drift
# ============== REMOVING DIRTY SITES:
# ... bregion  M1 ... event  fixon_preparation
# chan 1001 Replacing these trials with mean good trial: [932, 933, 934]
# chan 1005 Replacing these trials with mean good trial: [376, 377, 378]
# chan 1008 Replacing these trials with mean good trial: [376, 377, 378, 613, 614]
# chan 1010 Replacing these trials with mean good trial: [203, 204, 205, 355, 356, 357]
# chan 1013 Replacing these trials with mean good trial: [876, 877, 878]
# chan 1014 Replacing these trials with mean good trial: [200, 201, 202]
# chan 1018 Replacing these trials with mean good trial: [184, 185, 203, 204, 205, 710, 711, 723, 724]
# chan 1020 Replacing these trials with mean good trial: [789, 790]
# chan 1022 Replacing these trials with mean good trial: [38, 39, 40, 41, 42, 395]
# chan 1026 Replacing these trials with mean good trial: [630, 631, 632, 633]
# chan 1031 Replacing these trials with mean good trial: [470, 471]
# chan 1032 Replacing these trials with mean good trial: [376, 377, 378, 1021, 1022]
# chan 1041 Replacing these trials with mean good trial: [943, 944]
# chan 1042 Replacing these trials with mean good trial: [756, 757]
# chan 1043 Replacing these trials with mean good trial: [461, 462]
# chan 1048 Replacing these trials with mean good trial: [580, 581]
# chan 1049 Replacing these trials with mean good trial: [93, 94]
# ... bregion  PMv ... event  fixon_preparation
# Removing these bad chans: [1107, 1108]
# Chans exist in PA: [1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1082, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1127, 1128, 1129, 1130, 1428]
# chan 1059 Replacing these trials with mean good trial: [508, 509, 510, 511]
# chan 1060 Replacing these trials with mean good trial: [613, 614]
# chan 1061 Replacing these trials with mean good trial: [613, 614]
# chan 1062 Replacing these trials with mean good trial: [360, 361, 362, 363, 714, 715, 716, 717]
# chan 1063 Replacing these trials with mean good trial: [402, 403, 404, 405]
# chan 1064 Replacing these trials with mean good trial: [923, 924, 925]
# chan 1067 Replacing these trials with mean good trial: [406, 936]
# chan 1068 Replacing these trials with mean good trial: [936]
# chan 1073 Replacing these trials with mean good trial: [789, 790]
# chan 1074 Replacing these trials with mean good trial: [383, 384, 455, 945, 974]
# chan 1075 Replacing these trials with mean good trial: [789, 790]
# chan 1076 Replacing these trials with mean good trial: [936, 966]
# chan 1079 Replacing these trials with mean good trial: [714, 715, 716, 717, 819, 820]
# chan 1084 Replacing these trials with mean good trial: [446, 447, 936, 966]
# chan 1091 Replacing these trials with mean good trial: [203, 204, 205, 936]
# chan 1093 Replacing these trials with mean good trial: [203, 204, 205]
# chan 1094 Replacing these trials with mean good trial: [926, 927, 928]
# chan 1096 Replacing these trials with mean good trial: [53, 54, 859, 860]
# chan 1099 Replacing these trials with mean good trial: [402, 403, 404, 405]
# chan 1102 Replacing these trials with mean good trial: [613, 614]
# chan 1103 Replacing these trials with mean good trial: [720]
# chan 1106 Replacing these trials with mean good trial: [402, 403, 404, 405, 406, 407, 412]
# chan 1109 Replacing these trials with mean good trial: [376, 377, 378]
# chan 1113 Replacing these trials with mean good trial: [926, 927, 928]
# chan 1115 Replacing these trials with mean good trial: [360, 361, 362, 363, 948, 949]
# chan 1116 Replacing these trials with mean good trial: [936]
# chan 1118 Replacing these trials with mean good trial: [334, 360, 361, 362, 363, 936]
# chan 1119 Replacing these trials with mean good trial: [334, 360, 361, 362, 363, 489]
# ... bregion  PMd ... event  fixon_preparation
# chan 1138 Replacing these trials with mean good trial: [700, 701]
# chan 1140 Replacing these trials with mean good trial: [250, 251, 252, 721, 722]
# chan 1141 Replacing these trials with mean good trial: [212, 213, 214, 720]
# chan 1148 Replacing these trials with mean good trial: [694]
# chan 1151 Replacing these trials with mean good trial: [261, 262, 936]
# chan 1152 Replacing these trials with mean good trial: [373, 374, 375, 967, 968]
# chan 1158 Replacing these trials with mean good trial: [1028, 1029]
# chan 1161 Replacing these trials with mean good trial: [756, 757]
# chan 1163 Replacing these trials with mean good trial: [1017]
# chan 1164 Replacing these trials with mean good trial: [658, 659]
# chan 1165 Replacing these trials with mean good trial: [700, 701, 714, 715, 716, 717]
# chan 1168 Replacing these trials with mean good trial: [941, 942]
# ... bregion  dlPFC ... event  fixon_preparation
# chan 1177 Replacing these trials with mean good trial: [203, 204, 205]
# chan 1178 Replacing these trials with mean good trial: [575, 723, 724]
# chan 1182 Replacing these trials with mean good trial: [840, 841, 842]
# chan 1183 Replacing these trials with mean good trial: [908, 909]
# chan 1184 Replacing these trials with mean good trial: [995, 996, 997, 1003, 1004]
# chan 1188 Replacing these trials with mean good trial: [302, 303, 413, 414, 415, 919, 920, 1018, 1019, 1020]
# chan 1192 Replacing these trials with mean good trial: [122, 123, 124, 772, 773, 774]
# chan 1195 Replacing these trials with mean good trial: [725, 726]
# chan 1197 Replacing these trials with mean good trial: [186, 203, 204, 205, 723, 724]
# chan 1199 Replacing these trials with mean good trial: [840, 841, 842, 843, 844]
# chan 1204 Replacing these trials with mean good trial: [948, 949]
# chan 1435 Replacing these trials with mean good trial: [840, 841, 842, 931]
# ... bregion  vlPFC ... event  fixon_preparation
# Removing these bad chans: [1206, 1254]
# Chans exist in PA: [1205, 1206, 1207, 1208, 1209, 1211, 1212, 1213, 1215, 1216, 1217, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1438, 1439, 1440, 1441]
# chan 1205 Replacing these trials with mean good trial: [432, 433]
# chan 1208 Replacing these trials with mean good trial: [318, 319, 395, 754, 755, 941, 942]
# chan 1212 Replacing these trials with mean good trial: [432, 433]
# chan 1213 Replacing these trials with mean good trial: [55, 56, 57, 58, 152, 153]
# chan 1215 Replacing these trials with mean good trial: [540, 541, 542]
# chan 1220 Replacing these trials with mean good trial: [50, 51, 52]
# chan 1221 Replacing these trials with mean good trial: [318, 319]
# chan 1222 Replacing these trials with mean good trial: [936, 941, 942, 1008]
# chan 1224 Replacing these trials with mean good trial: [184, 185, 1008]
# chan 1225 Replacing these trials with mean good trial: [432, 433]
# chan 1226 Replacing these trials with mean good trial: [990, 991, 992]
# chan 1228 Replacing these trials with mean good trial: [499, 500, 969]
# chan 1229 Replacing these trials with mean good trial: [837, 838, 839]
# chan 1231 Replacing these trials with mean good trial: [68, 69, 70]
# chan 1233 Replacing these trials with mean good trial: [203, 204, 205]
# chan 1234 Replacing these trials with mean good trial: [53, 54]
# chan 1237 Replacing these trials with mean good trial: [818]
# chan 1240 Replacing these trials with mean good trial: [840, 841, 842]
# chan 1245 Replacing these trials with mean good trial: [948, 949]
# chan 1249 Replacing these trials with mean good trial: [443, 936, 1008]
# chan 1255 Replacing these trials with mean good trial: [903, 904, 905, 906, 907, 923, 924, 925, 936]
# chan 1256 Replacing these trials with mean good trial: [68, 69, 70]
# chan 1258 Replacing these trials with mean good trial: [707, 708, 721, 722, 723, 724]
# chan 1440 Replacing these trials with mean good trial: [501, 660, 661, 936, 995, 996, 997, 1008]
# ... bregion  FP ... event  fixon_preparation
# chan 1260 Replacing these trials with mean good trial: [818]
# chan 1261 Replacing these trials with mean good trial: [818]
# chan 1264 Replacing these trials with mean good trial: [434, 435, 436, 466, 467, 468, 469, 513, 514, 515]
# chan 1265 Replacing these trials with mean good trial: [203, 204, 205, 870, 871, 872]
# chan 1268 Replacing these trials with mean good trial: [754, 755]
# chan 1270 Replacing these trials with mean good trial: [606, 818]
# chan 1272 Replacing these trials with mean good trial: [710, 711]
# chan 1273 Replacing these trials with mean good trial: [466, 467, 468, 469, 1047, 1048]
# chan 1275 Replacing these trials with mean good trial: [0, 1, 2, 604, 605, 658, 659, 664, 665, 666, 667]
# chan 1279 Replacing these trials with mean good trial: [76, 77]
# chan 1280 Replacing these trials with mean good trial: [169, 170, 171, 890, 891]
# chan 1281 Replacing these trials with mean good trial: [660, 661, 936]
# chan 1282 Replacing these trials with mean good trial: [779, 780, 781]
# chan 1284 Replacing these trials with mean good trial: [748, 749, 750]
# chan 1286 Replacing these trials with mean good trial: [237, 238, 239]
# chan 1290 Replacing these trials with mean good trial: [1005, 1006, 1007]
# chan 1294 Replacing these trials with mean good trial: [190, 191, 247, 248, 249, 1039, 1040]
# chan 1295 Replacing these trials with mean good trial: [237, 238, 239]
# chan 1297 Replacing these trials with mean good trial: [686, 687, 818]
# ... bregion  SMA ... event  fixon_preparation
# Removing these bad chans: [1312, 1341]
# Chans exist in PA: [1298, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1310, 1311, 1312, 1313, 1315, 1316, 1317, 1318, 1319, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1330, 1331, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1350, 1351, 1442, 1443, 1444, 1445]
# chan 1302 Replacing these trials with mean good trial: [533, 534, 535, 576, 577]
# chan 1303 Replacing these trials with mean good trial: [694]
# chan 1304 Replacing these trials with mean good trial: [725, 726]
# chan 1305 Replacing these trials with mean good trial: [754, 755, 919, 920]
# chan 1306 Replacing these trials with mean good trial: [203, 204, 205, 931]
# chan 1308 Replacing these trials with mean good trial: [727]
# chan 1317 Replacing these trials with mean good trial: [694, 738, 739, 740, 741, 742, 743, 744, 747, 748, 749, 750]
# chan 1321 Replacing these trials with mean good trial: [1047, 1048]
# chan 1323 Replacing these trials with mean good trial: [709]
# chan 1324 Replacing these trials with mean good trial: [437, 438, 439, 615, 616]
# chan 1326 Replacing these trials with mean good trial: [791, 792]
# chan 1328 Replacing these trials with mean good trial: [519, 520]
# chan 1336 Replacing these trials with mean good trial: [376, 377, 378]
# chan 1338 Replacing these trials with mean good trial: [710, 711, 756, 757]
# chan 1343 Replacing these trials with mean good trial: [74, 75]
# chan 1346 Replacing these trials with mean good trial: [355, 356, 357]
# chan 1348 Replacing these trials with mean good trial: [472, 473, 474]
# chan 1351 Replacing these trials with mean good trial: [376, 377, 378, 1041, 1042, 1043]
# chan 1442 Replacing these trials with mean good trial: [477, 478, 694]
# chan 1443 Replacing these trials with mean good trial: [720]
# ... bregion  preSMA ... event  fixon_preparation
# Removing these bad chans: [1405, 1451]
# Chans exist in PA: [1352, 1353, 1355, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1380, 1381, 1382, 1383, 1384, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1401, 1405, 1406, 1408, 1409, 1411, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1446, 1448, 1450, 1451, 1452]
# chan 1353 Replacing these trials with mean good trial: [926, 927, 928]
# chan 1357 Replacing these trials with mean good trial: [941, 942]
# chan 1358 Replacing these trials with mean good trial: [932, 933, 934]
# chan 1364 Replacing these trials with mean good trial: [958, 959]
# chan 1366 Replacing these trials with mean good trial: [315, 316, 317, 395, 402, 403, 404, 405, 837, 838, 839]
# chan 1368 Replacing these trials with mean good trial: [1039, 1040]
# chan 1369 Replacing these trials with mean good trial: [203, 204, 205]
# chan 1370 Replacing these trials with mean good trial: [315, 316, 317]
# chan 1371 Replacing these trials with mean good trial: [1008]
# chan 1374 Replacing these trials with mean good trial: [923, 924, 925, 926, 927, 928, 967, 968]
# chan 1375 Replacing these trials with mean good trial: [118, 119, 120, 121, 396, 397]
# chan 1376 Replacing these trials with mean good trial: [203, 204, 205, 358, 359, 426, 427, 428, 700, 701]
# chan 1378 Replacing these trials with mean good trial: [184, 185]
# chan 1382 Replacing these trials with mean good trial: [315, 316, 317, 936]
# chan 1384 Replacing these trials with mean good trial: [203, 204, 205, 206, 207, 208, 209, 389, 466, 467, 468, 469]
# chan 1387 Replacing these trials with mean good trial: [432, 433, 437, 438, 439, 554, 555, 704, 705, 706]
# chan 1388 Replacing these trials with mean good trial: [203, 204, 205]
# chan 1391 Replacing these trials with mean good trial: [426, 427, 428]
# chan 1392 Replacing these trials with mean good trial: [406]
# chan 1393 Replacing these trials with mean good trial: [318, 319]
# chan 1394 Replacing these trials with mean good trial: [963]
# chan 1395 Replacing these trials with mean good trial: [956, 957]
# chan 1397 Replacing these trials with mean good trial: [203, 204, 205]
# chan 1398 Replacing these trials with mean good trial: [941, 942]
# chan 1401 Replacing these trials with mean good trial: [658, 659]
# chan 1408 Replacing these trials with mean good trial: [966]
# chan 1409 Replacing these trials with mean good trial: [966]
# chan 1411 Replacing these trials with mean good trial: [250, 251, 252, 519, 520, 646, 647, 721, 722]
# chan 1418 Replacing these trials with mean good trial: [694, 826, 827, 828, 941, 942, 966]
# chan 1419 Replacing these trials with mean good trial: [1021, 1022]
# chan 1420 Replacing these trials with mean good trial: [610, 611, 612]
# chan 1422 Replacing these trials with mean good trial: [135, 136]
# chan 1423 Replacing these trials with mean good trial: [977, 978, 979]
# chan 1424 Replacing these trials with mean good trial: [926, 927, 928]
# chan 1448 Replacing these trials with mean good trial: [963]
# chan 1450 Replacing these trials with mean good trial: [936]
# PA.X.shape, before and after dfallpa_preprocess_sitesdirty_single
# ('M1', 'fixon_preparation', (-0.4, 0.4)) (43, 1054, 80)  -->  (43, 1054, 80)
# ('PMv', 'fixon_preparation', (-0.4, 0.4)) (68, 1054, 80)  -->  (66, 1054, 80)
# ('PMd', 'fixon_preparation', (-0.4, 0.4)) (36, 1054, 80)  -->  (36, 1054, 80)
# ('dlPFC', 'fixon_preparation', (-0.4, 0.4)) (24, 1054, 80)  -->  (24, 1054, 80)
# ('vlPFC', 'fixon_preparation', (-0.4, 0.4)) (54, 1054, 80)  -->  (52, 1054, 80)
# ('FP', 'fixon_preparation', (-0.4, 0.4)) (35, 1054, 80)  -->  (35, 1054, 80)
# ('SMA', 'fixon_preparation', (-0.4, 0.4)) (51, 1054, 80)  -->  (49, 1054, 80)
# ('preSMA', 'fixon_preparation', (-0.4, 0.4)) (66, 1054, 80)  -->  (64, 1054, 80)
#  == (3) Remove low FR chans
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1001, 1002, 1004, 1005, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1018, 1020, 1021, 1022, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1035, 1036, 1038, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1053, 1055, 1056, 1057, 1426]
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1082, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1106, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1127, 1128, 1129, 1130, 1428]
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1144, 1145, 1146, 1148, 1149, 1151, 1152, 1153, 1154, 1155, 1158, 1160, 1161, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1173, 1174, 1433]
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1175, 1177, 1178, 1179, 1180, 1182, 1183, 1184, 1187, 1188, 1190, 1191, 1192, 1193, 1195, 1196, 1197, 1198, 1199, 1200, 1202, 1203, 1204, 1435]
# ----
# **Removing these bad chans: [1439]
#   Keeping these good chans: [1205, 1207, 1208, 1209, 1211, 1212, 1213, 1215, 1216, 1217, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1249, 1250, 1251, 1252, 1253, 1255, 1256, 1257, 1258, 1438, 1440, 1441]
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1260, 1261, 1263, 1264, 1265, 1266, 1267, 1268, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297]
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1298, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1310, 1311, 1313, 1315, 1316, 1317, 1318, 1319, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1330, 1331, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1350, 1351, 1442, 1443, 1444, 1445]
# ----
# **Removing these bad chans: []
#   Keeping these good chans: [1352, 1353, 1355, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1380, 1381, 1382, 1383, 1384, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1401, 1406, 1408, 1409, 1411, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1446, 1448, 1450, 1452]
#  == (4) Remove bad chans, low FR, low signal
# (43, 1054, 80)
# Keep, for  M1  ... 43 / 43
#  ... keeping:  [1001, 1002, 1004, 1005, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1018, 1020, 1021, 1022, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1035, 1036, 1038, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1053, 1055, 1056, 1057, 1426]
#  ... excluding:  []
# (66, 1054, 80)
# Keep, for  PMv  ... 66 / 66
#  ... keeping:  [1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1082, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1106, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1127, 1128, 1129, 1130, 1428]
#  ... excluding:  []
# (36, 1054, 80)
# Keep, for  PMd  ... 36 / 36
#  ... keeping:  [1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1144, 1145, 1146, 1148, 1149, 1151, 1152, 1153, 1154, 1155, 1158, 1160, 1161, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1173, 1174, 1433]
#  ... excluding:  []
# (24, 1054, 80)
# Keep, for  dlPFC  ... 24 / 24
#  ... keeping:  [1175, 1177, 1178, 1179, 1180, 1182, 1183, 1184, 1187, 1188, 1190, 1191, 1192, 1193, 1195, 1196, 1197, 1198, 1199, 1200, 1202, 1203, 1204, 1435]
#  ... excluding:  []
# (51, 1054, 80)
# Keep, for  vlPFC  ... 51 / 51
#  ... keeping:  [1205, 1207, 1208, 1209, 1211, 1212, 1213, 1215, 1216, 1217, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1249, 1250, 1251, 1252, 1253, 1255, 1256, 1257, 1258, 1438, 1440, 1441]
#  ... excluding:  []
# (35, 1054, 80)
# Keep, for  FP  ... 35 / 35
#  ... keeping:  [1260, 1261, 1263, 1264, 1265, 1266, 1267, 1268, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297]
#  ... excluding:  []
# (49, 1054, 80)
# Keep, for  SMA  ... 48 / 49
#  ... keeping:  [1298, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1310, 1311, 1313, 1315, 1316, 1317, 1318, 1319, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1330, 1331, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1350, 1351, 1442, 1443, 1444, 1445]
#  ... excluding:  [1340]
# (64, 1054, 80)
# Keep, for  preSMA  ... 64 / 64
#  ... keeping:  [1352, 1353, 1355, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1380, 1381, 1382, 1383, 1384, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1401, 1406, 1408, 1409, 1411, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1446, 1448, 1450, 1452]
#  ... excluding:  []
#  == (5) Sqrt transform
#  == (6) Normalize FR
# Running ..  M1
# Running ..  PMv
# Running ..  PMd
# Running ..  dlPFC
# Running ..  vlPFC
# Running ..  FP
# Running ..  SMA
# Running ..  preSMA
#  == (7) Sort trials by trialcode

# %%
# Method 2 - Combine two dfallpa
animal = "Diego"
date = 230630
COMBINE_AREAS = True

# animal = "Pancho"
# date = 230626
# COMBINE_AREAS = False

DFallpa1 = load_handsaved_wrapper(animal=animal, date=date, version="trial", combine_areas=COMBINE_AREAS, use_time=True)

which_level = "saccade_fix_on"
DFallpa2 = load_handsaved_wrapper(animal=animal, date=date, version=which_level, combine_areas=COMBINE_AREAS, use_time=True)

# DFallpa2 = load_handsaved_wrapper(animal=animal, date=date, version="stroke", combine_areas=COMBINE_AREAS, use_time=True)

DFallpa = pd.concat([DFallpa1, DFallpa2]).reset_index(drop=True)

from neuralmonkey.classes.population_mult import dfpa_concatbregion_preprocess_wrapper
fr_normalization_method = "across_time_bins"
dfpa_concatbregion_preprocess_wrapper(DFallpa, fr_mean_subtract_method=fr_normalization_method)

# %%
# Add variables
def f(smi):
    if smi == -1:
        return "withinfixation"
    elif smi in [0,1]:
        return "early"
    elif smi>1:
        return "late"
    else:
        assert False
for pa in DFallpa["pa"]:
    dflab = pa.Xlabels["trials"]
    if "shape-macrosaccade-index" in dflab.columns:
        dflab["early_late_by_smi"] = [f(smi) for smi in dflab["shape-macrosaccade-index"]]

# %% [markdown]
# # Sanity check - extracted fixations

# %%
DFallpa
PA = DFallpa["pa"].values[1]
dflab = PA.Xlabels["trials"]

# %%
tc = sorted(dflab["trialcode"].unique())[20]

# tc = "230626-2-151"

dfthis = dflab[dflab["trialcode"] == tc]

print(tc)
dfthis.loc[:, ["shape-fixation", "event_time", "event_idx_within_trial", "first-fixation-on-shape", "shape-macrosaccade-index"]]
# Out:
# 230615-2-6
#      shape-fixation  event_time  event_idx_within_trial  \
# 12  squiggle3-3-2-0    2.605837                       0
# 13  squiggle3-3-2-0    2.815888                       1
# 14  squiggle3-3-2-0    3.381026                       3
# 15  squiggle3-3-2-0    3.791127                       5
#
#     first-fixation-on-shape  shape-macrosaccade-index
# 12                     True                       1.0
# 13                    False                      -1.0
# 14                     True                       2.0
# 15                     True                       3.0

# %%
# NOTE: Confirmed that fixations are correct, relative to what I plotted in timecourse.

# %% [markdown]
# # State space plots (shape-fixation vs. seqc_0_shape)

# %%
SAVEDIR_ANALYSIS = f"/lemur2/lucas/analyses/recordings/main/eyetracking_analyses/SUBSPACES/{animal}-{date}"
os.makedirs(SAVEDIR_ANALYSIS, exist_ok=True)

# %% [markdown]
# ### Plot scalar values (time-mean within twindow)

# %%
DFallpa = DFallpa[DFallpa["bregion"] == "PMv_m"].reset_index(drop=True)

# %%
pa = DFallpa["pa"].values[0]
dflab = pa.Xlabels["trials"]
from pythonlib.tools.pandastools import grouping_print_n_samples, append_col_with_grp_index
grouping_print_n_samples(dflab, ["between-stimonset-and-go", "early-or-late-planning-period", "is-first-macrosaccade", "shape-macrosaccade-index", "event_idx_within_trial", "first-fixation-on-shape"])

# %%
pa = DFallpa["pa"].values[0]
pa.Xlabels["trials"]["seqc_0_shape"].value_counts()

# %%
shapes_keep = [sh for sh in dflabthis["seqc_0_shape"].unique() if len(dflabthis[dflabthis["seqc_0_shape"]==sh]["trialcode"].unique())>n_min]

# %%
from neuralmonkey.scripts.analy_eyefixation_PCA_statespace import plot_all

plot_all(DFallpa, SAVEDIR_ANALYSIS)

# %%
dflab = pa.Xlabels["trials"]
dflab["event_time"]

# %%
sorted(dflab.columns)

# %% [markdown]
# # Decode (generalize from draw to visual)

# %%
# Categorical decoder.

# %%
# NOTE: this doesnt do that well --> Reason: there is strong bias to predict the shape that is being controleld (seqc_0_shape).

# %%
## Cross-temporal decoder, trained on seqc_0_shape, tested on shape-fixation
from neuralmonkey.analyses.decode_good import decodewrapouterloop_categorical_cross_time_cross_var, decodewrapouterloop_categorical_cross_time_plot

SAVEDIR_ANALYSIS = f"/lemur2/lucas/analyses/recordings/main/eyetracking_analyses/DECODERS/{animal}-{date}"
SAVEDIR_ANALYSIS = f"/tmp/{animal}-{date}"

SAVEDIR = f"{SAVEDIR_ANALYSIS}/cross_temporal_diff_var_train_test"
os.makedirs(SAVEDIR, exist_ok=True)

# %%
filtdict_train = {
    "FEAT_num_strokes_beh":[1],
    "FEAT_num_strokes_task":[1],
}

# %%
DFallpa

# %%
filtdict_train = {}

# %%
filtdict_train

# %%
filtdict_test = {"shape-macrosaccade-index":[1]}
# grouping_print_n_samples(dflab, ["between-stimonset-and-go", "early-or-late-planning-period", "is-first-macrosaccade", "shape-macrosaccade-index", "event_idx_within_trial", "first-fixation-on-shape"])

# %%
# time_bin_size = 0.1
# slide=0.02

time_bin_size = 0.2
slide=0.1

list_var_decode_train_test = [
    ('seqc_0_shape', 'shape-fixation'), 
    # ('seqc_0_shape', 'seqc_0_shape'), 
    # ('shape-fixation', 'shape-fixation')
    ]

assert len(DFallpa["twind"].unique())==1, "not big deal. just change code below to iter over all (ev, tw)."

DFRES = decodewrapouterloop_categorical_cross_time_cross_var(DFallpa,
                                                     list_var_decode_train_test,
                                                         time_bin_size, slide, savedir=SAVEDIR, extract_params=False,
                                                            ignore_same_events=False, which_level="flex",
                                                            filtdict_train=filtdict_train,
                                                            filtdict_test=filtdict_test,
                                                            do_split_train_by_context=True, vars_conj_train = ["shape-fixation"],
                                                            do_split_test_by_context=True, vars_conj_test = ["seqc_0_shape"],
)
if len(DFRES)>0:
    decodewrapouterloop_categorical_cross_time_plot(DFRES, SAVEDIR)

# %%
from pythonlib.tools.pandastools import grouping_print_n_samples, stringify_values
DFRES = stringify_values(DFRES)
grouping_print_n_samples(DFRES, ["bregion", "event_train", "event_test", 
                                 "task_kind_train", "task_kind_test", 
                                 "var_decode_train", "var_decode_test", 
                                 "vars_conj_train", "vars_conj_test",
                                 "grp_train", "grp_test"])

# %%
from pythonlib.tools.pandastools import grouping_print_n_samples, stringify_values
DFRES = stringify_values(DFRES)
grouping_print_n_samples(DFRES, ["bregion", "event_train", "event_test", 
                                 "task_kind_train", "task_kind_test", 
                                 "var_decode_train", "var_decode_test", 
                                 "vars_conj_train", "vars_conj_test",
                                 "grp_train", "grp_test"])

# %%
from pythonlib.tools.pandastools import grouping_print_n_samples, stringify_values
DFRES = stringify_values(DFRES)
grouping_print_n_samples(DFRES, ["bregion", "event_train", "event_test", 
                                 "task_kind_train", "task_kind_test", 
                                 "var_decode_train", "var_decode_test", 
                                 "vars_conj_train", "vars_conj_test",
                                 "grp_train", "grp_test"])

# %%
DFRES

# %%
tmp = DFRES["labels_exist_test"].values[0]
str(tmp)

# %%
pa.

# %% [markdown]
# # Decode (moment) - generalize betwee seqc_0_shape and shape-fixation

# %%
# bregion = "PMd_p"
bregion = "PMv_m"
savedir = f"/tmp/Pancho/{bregion}"
# bregion = "PMv"

# %%
from neuralmonkey.scripts.analy_eyefixation_decode_moment_generalize import plot_all
plot_all(DFallpa, bregion, savedir, plot_each_other_var=False)

# %%
dfsummary, _, _, _, _ = summarize_featurediff(DFSCORES, "same_class", [False, True], [var_score], 
                    ["decoder_class_good", "decoder_class_is_in_pa", "pa_class", 
                     "pa_class_is_in_decoder", "pa_idx", "trialcode", "twind", "seqc_0_shape", VAR_EARLY_LATE
                     ])

# %%
var_score = "score_norm"
var_condition = "decoder_class"
dfsummary, _, _, _, _ = summarize_featurediff(DFSCORES, "same_class", [False, True], [var_score], 
                    ["decoder_class_good", "decoder_class_is_in_pa", var_condition, "twind"])

# %%
dfsummary

# %%
# savedirthis = f"{savedir}/COMBINED-{dfscores_ver}-{var_score}"
# os.makedirs(savedirthis, exist_ok=True)
dfscores_this= dfsummary
var_score_this= f"{var_score}-TrueminFalse"

fig = sns.catplot(data=dfscores_this, x=VAR_EARLY_LATE, y=var_score_this, hue="twind", alpha=0.2, jitter=True)
for ax in fig.axes.flatten():
    ax.axhline(0, color="k", alpha=0.5)
# rotateLabel(fig)
# savefig(fig, f"{savedirthis}/early_vs_late-1.pdf")

fig = sns.catplot(data=dfscores_this, x=VAR_EARLY_LATE, y=var_score_this, hue="twind", kind="bar", errorbar=("ci", 68))
for ax in fig.axes.flatten():
    ax.axhline(0, color="k", alpha=0.5)
# rotateLabel(fig)
# savefig(fig, f"{savedirthis}/early_vs_late-2.pdf")

fig = sns.catplot(data=dfscores_this, x=VAR_EARLY_LATE, y=var_score_this, hue="seqc_0_shape", col="twind", kind="point", errorbar=("ci", 68))
for ax in fig.axes.flatten():
    ax.axhline(0, color="k", alpha=0.5)
# rotateLabel(fig)
# savefig(fig, f"{savedirthis}/early_vs_late-3.pdf")

# %%
sns.catplot(data=dfsummary, x="is-first-macrosaccade", y=f"{var_score}-TrueminFalse",)

# %%
# Early vs. late, only keep if

# %% [markdown]
# # Compare decoder matches seqc_0_shape or shape-fixation, for fixations that disosciate those things

# %%
SAVEDIR = "/tmp"
bregion = "PMv"

# %% [markdown]
# ##### Make the plots

# %%
from neuralmonkey.scripts.analy_eyefixation_decode_moment_generalize import plot_scatter_dissociate_draw_fix, _plot_scatter_dissociate_draw_fix
bregion = "PMv"
SAVEDIR_ALL = "/tmp/DISSOC"
os.makedirs(SAVEDIR_ALL, exist_ok=True)
plot_scatter_dissociate_draw_fix(DFallpa, bregion, SAVEDIR_ALL)

# %%
dfscores

# %%
from pythonlib.tools.pandastools import extract_with_levels_of_conjunction_vars_helper
dfout, dict_dfthis = extract_with_levels_of_conjunction_vars_helper(dfscores, "early_late_by_eidx", ["trialcode", "shape_draw_fix", "twind"])

print(len(dfscores))
print(len(dfout))

# %%
from pythonlib.tools.pandastools import grouping_print_n_samples
grouping_print_n_samples(dfscores, )

# %% [markdown]
# ##### Method based on recoding

# %%
dfscores_this_wide

# %%
# TODO: keep only event_idx that have at least n points.
# TODO: restrict to most ambiguous taskconfig loc.
# TODO: keep only trials that have pts early and late (and somehow plot individual trials?)
# TODO: whether to normalize decoders? no need
# ---> Yes, need to show that fixation effect is larger than when not fixating (i.e., cases with drawing that thing, but not fixating)
# TODO: Somehow shuffle to show that depends on fixations?

# %%
# Only keep trials that have early and late fixation
dflab

# %% [markdown]
# ### Find trials where switch between different fixations early

# %%
dflab["trialcode"]

# %%
event_idxs

# %%
# Given a trialcode, determine its sequence of fixations
list_tc = dflab["trialcode"].unique().tolist()

map_tc_to_shapefixseq ={}
map_tc_to_eventidxs ={}
map_tc_to_shapedraw ={}

res = []
for tc in list_tc:
    dfthis = dflab[dflab["trialcode"] == tc]

    event_idxs = dfthis["event_idx_within_trial"].tolist()
    # assert event_idxs == list(range(len(event_idxs))) # Not necessariyl true...
    assert sorted(event_idxs) == event_idxs, "no problem just need to sort shape fix sequence"
    
    shape_fix_seq = tuple(dfthis["shape-fixation"].tolist())
    if len(shape_fix_seq)>1:
        shape_fix_seq_first_two = shape_fix_seq[:2]
    else:
        shape_fix_seq_first_two = ("IGN", "IGN")

    if len(shape_fix_seq)>2:
        shape_fix_seq_first_three = shape_fix_seq[:3]
    else:
        shape_fix_seq_first_three = ("IGN", "IGN", "IGN")

    tmp = list(set(dfthis["seqc_0_shape"].tolist()))
    assert len(tmp)==1
    shape_draw = tmp[0]

    map_tc_to_shapedraw[tc] = shape_draw
    map_tc_to_shapefixseq[tc] = shape_fix_seq
    map_tc_to_eventidxs[tc] = tuple(event_idxs)

    res.append({
        "trialcode":tc,
        "seqc_0_shape":shape_draw,
        "shape_fix_seq":shape_fix_seq,
        "shape_fix_seq_first_two":shape_fix_seq_first_two,
        "shape_fix_seq_first_three":shape_fix_seq_first_three,
        "event_idxs":tuple(event_idxs)
    })

df_tcmap = pd.DataFrame(res)
df_tcmap

# %%
grouping_plot_n_samples_conjunction_heatmap(df_tcmap, "shape_fix_seq_first_three", "seqc_0_shape")

# %%
grouping_plot_n_samples_conjunction_heatmap(df_tcmap, "shape_fix_seq_first_two", "seqc_0_shape")

# %%
df_tcmap["shape_fix_seq_first_two"].value_counts()
